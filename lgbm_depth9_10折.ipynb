# %%
import pandas as pd
from tqdm import tqdm
import warnings
import gc
import os
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from gensim.models import Word2Vec
from collections import OrderedDict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score
import time
from itertools import combinations

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def reduce_mem(df):
    starttime = time.time()
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if pd.isnull(c_min) or pd.isnull(c_max):
                continue
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    print('-- Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction),time spend:{:2.2f} min'.format(end_mem,
                                                                                                           100*(start_mem-end_mem)/start_mem,
                                                                                                           (time.time()-starttime)/60))
    return df

# %%
seed = 1024

# %%
df_train = pd.read_csv('/home/mw/input/pre8881/train.csv')
# df_test = pd.read_csv('/home/mw/input/pretest_a3048/test_a.csv')
df_test_b = pd.read_csv('/home/mw/input/pretest_b6354/test_b.csv')
df_train['flag'], df_test_b['flag'] = 0, 2
df_train.shape, df_test_b.shape
# Out:
# ((684283, 66), (80110, 65))

# %% [markdown]
# ## 采样

# %%
# train_label_0 = df_train_all[ df_train_all['y1_is_purchase'] == 0 ]
# train_label_1 = df_train_all[ df_train_all['y1_is_purchase'] == 1 ]
# print(train_label_0.shape, train_label_1.shape)

# train_label_0 = train_label_0.sample(n = 253759 , random_state = seed).reset_index(drop=True)
# train_label_1 = train_label_1.sample(n = 430524 , random_state = seed).reset_index(drop=True)
# print(train_label_0.shape, train_label_1.shape)

# df_train = pd.concat([train_label_0,train_label_1]).reset_index(drop=True)
# df_train = df_train.sample(frac = 1, random_state = seed+1 ).reset_index(drop=True)
# print(df_train.shape)
# print(df_train['y1_is_purchase'].value_counts())

# %%
df_feature = pd.concat([df_train,df_test_b]).reset_index(drop=True)
df_feature = reduce_mem(df_feature)

del df_train, df_test_b
gc.collect()
df_feature.head()
# Out:
# -- Mem. usage decreased to 217.24 Mb (43.6% reduction),time spend:0.01 min
#                   client_no  dpt  xz  xb  \
# 0  5gDljzjQ61m/QeU2tZBgDA==  217  商交  主全
# 1  qTsiFUfrw8gwVOM+LftPvA==  217  商交  主全
# 2  vfTADBw3uqyLukTz5juO0g==  217  商交  主全
# 3  zP5cmQ2nwzLbvocQPmf2YA==  217  商交  主全
# 4  +ruD5NLealUAfMZPQd6LEw==  217  单交  单交
#
#                                           carid  nprem_ly    ncd_ly  newvalue  \
# 0  WY4N+MOjfIx8wJ3j6GhlA4qEfL71brEUkqbB0SSdqkI=    1391.0  0.600098     88900
# 1  DXMuODygH0ddFea7SIoAOhF4134Bx4TPvkkPi6WCdzU=    3740.0  1.000000    303000
# 2  waWCEYZJqj9PYxFdVeVLkpCNf/n0BdXPFi1iHlk0WWk=    1454.0  0.600098    132800
# 3  nyRm/VviYGDpy2errRWE206SaYkVuqeclusAtXEU9v8=    3526.0  0.850098    316800
# 4  LacSDMaoqD0AJRqCeYaGUu343r4NQiVuiFc9hyjLcMI=     522.5       NaN    247800
#
#    bi_renewal_year  clmnum              regdate trademark_cn brand_cn  \
# 0                6       0  2010-02-09 00:00:00           福特  长安福特马自达
# 1                6       0  2007-02-02 00:00:00           丰田     天津丰田
# 2                6       0  2007-01-01 00:00:00           长城     长城汽车
# 3                5       2  2015-02-09 00:00:00           奥迪     一汽大众
# 4                3       0  2017-12-12 00:00:00           大众     上汽大众
#
#                 make_cn series     capab  seats use_type change_owner  \
# 0          福特CAF7152A轿车    嘉年华  1.498047      5      非营业        非过户投保
# 1      丰田TV7250RoyalA轿车     皇冠  2.496094      5      非营业        非过户投保
# 2       长城CC6460KM60旅行车     哈弗  2.771484      5      非营业        非过户投保
# 3       奥迪FV7201BACBG轿车     A6  1.984375      5      非营业        非过户投保
# 4  大众汽车SVW6474CED多用途乘用车     途观  1.797852      5      非营业        非过户投保
#
#    nprem_od     si_od  nprem_tp    si_tp  nprem_bt     si_bt  nprem_vld  \
# 0    379.00   24892.0   239.250  1000000     0.000       0.0   3.750000
# 1   1993.00   60600.0   505.500  1000000    72.375   60600.0   0.000000
# 2    434.75   26560.0   251.375  1000000     0.000       0.0   0.000000
# 3   1651.00  202752.0   381.000  1000000   141.625  202752.0  17.921875
# 4      0.00       0.0     0.000        0     0.000       0.0   0.000000
#
#    si_vld  nprem_vlp  si_vlp  p1_prior_days_to_insure  \
# 0   10000   9.507812   10000                     30.0
# 1       0   0.000000       0                     27.0
# 2       0   0.000000       0                     30.0
# 3   30000  45.468750   30000                     27.0
# 4       0   0.000000       0                      1.0
#
#    suiche_nonauto_nprem_20  suiche_nonauto_nprem_19  suiche_nonauto_nprem_18  \
# 0                      NaN                      NaN                      NaN
# 1               390.000000                  0.00000                      0.0
# 2               350.000000                  0.00000                      0.0
# 3                 9.898438                 19.90625                      0.0
# 4                 0.000000                  0.00000                      0.0
#
#    suiche_nonauto_nprem_17  suiche_nonauto_nprem_16  suiche_nonauto_amount_20  \
# 0                      NaN                      NaN                       NaN
# 1                    170.0                    170.0                 2795000.0
# 2                      0.0                      0.0                 1695000.0
# 3                    170.0                      0.0                 1000000.0
# 4                      0.0                      0.0                       0.0
#
#    suiche_nonauto_amount_19  suiche_nonauto_amount_18  \
# 0                       NaN                       NaN
# 1                       0.0                       0.0
# 2                       0.0                       0.0
# 3                 1000000.0                       0.0
# 4                       0.0                       0.0
#
#    suiche_nonauto_amount_17  suiche_nonauto_amount_16  num_notcar_claim  \
# 0                       NaN                       NaN               NaN
# 1                  120000.0                  120000.0               NaN
# 2                       0.0                       0.0               NaN
# 3                  120000.0                       0.0               NaN
# 4                       0.0                       0.0               NaN
#
#                   p1_gender  p1_age  \
# 0  jh4mxXNEalwumcCWUJdnBw==    56.0
# 1  jh4mxXNEalwumcCWUJdnBw==    52.0
# 2  jh4mxXNEalwumcCWUJdnBw==    55.0
# 3  jh4mxXNEalwumcCWUJdnBw==    47.0
# 4  yUh7960km3oydK6Km9rqRA==    52.0
#
#                              p1_census_register         p2_marital_status  \
# 0  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 1  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 2  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 3  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 4  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
#
#   f1_child_flag f2_posses_house_flag  f2_cust_housing_price_total  \
# 0             是                    是                        0.000
# 1             是                    是                        0.000
# 2             是                    是                      154.625
# 3             是                    是                      208.000
# 4             否                    是                        0.000
#
#   p2_client_grade w1_pc_wx_use_flag p1_is_bank_eff p2_is_enterprise_owner  \
# 0    车主俱乐部-钻石客户-2                 是              否                    NaN
# 1    车主俱乐部-钻石客户-2                 是              否                      是
# 2    车主俱乐部-钻石客户-2                 否              是                      否
# 3    车主俱乐部-钻石客户-2                 是              是                      是
# 4    车主俱乐部-钻石客户-2                 是              否                      是
#
#   p2_is_smeowner  active_7  active_30  active_90  active_365  \
# 0            NaN       0.0        0.0        3.0        32.0
# 1              是       2.0        4.0       11.0        40.0
# 2              否       0.0        0.0        9.0        17.0
# 3              是       0.0        0.0        1.0         7.0
# 4              是       0.0        1.0       11.0        30.0
#
#   p2_is_child_under_15_family p2_is_adult_over_55_family birth_month  \
# 0                           否                          是          6月
# 1                           否                          否          9月
# 2                           否                          否          2月
# 3                           否                          否          7月
# 4                           否                          否         11月
#
#    p1_service_offer_cnt  p3_service_use_cnt  dur_personal_insurance_90  \
# 0                   0.0                 0.0                        NaN
# 1                   0.0                 0.0                        NaN
# 2                   0.0                 0.0                        NaN
# 3                   0.0                 0.0                   151786.0
# 4                   0.0                 0.0                        NaN
#
#    service_score_available  y1_is_purchase  flag
# 0                      0.0             0.0     0
# 1                     10.0             1.0     0
# 2                     16.0             1.0     0
# 3                      0.0             1.0     0
# 4                      1.0             1.0     0

# %% [markdown]
# ## 数据处理

# %%
# 异常值，长尾特征处理
# df_feature['p1_prior_days_to_insure'] = df_feature['p1_prior_days_to_insure'].apply(lambda x: -1 if x<0 else x)
# df_feature['p1_prior_days_to_insure'] = df_feature['p1_prior_days_to_insure'].apply(lambda x: 91 if x>90 else x)
# df_feature['p1_age'] = df_feature['p1_age'].apply(lambda x: 80 if x>=80 else x)
# df_feature['p1_age'] = df_feature['p1_age'].apply(lambda x: 18 if x<=18 else x)
# df_feature['p1_service_offer_cnt'] = df_feature['p1_service_offer_cnt'].apply(lambda x: 0 if x>=100 or x<0 else x)
# df_feature['p1_service_offer_cnt'] = df_feature['p1_service_offer_cnt'].apply(lambda x: 25 if x>=25 else x)
# df_feature['p1_service_offer_cnt'] = df_feature['p1_service_offer_cnt'].apply(lambda x: 20 if x>=20 and x<25 else x)
# df_feature['p3_service_use_cnt'] = df_feature['p3_service_use_cnt'].apply(lambda x: 0 if x>=80 or x<0 else x)
# df_feature['p3_service_use_cnt'] = df_feature['p3_service_use_cnt'].apply(lambda x: 15 if x>=15 else x)
# df_feature['p3_service_use_cnt'] = df_feature['p3_service_use_cnt'].apply(lambda x: 10 if x>=10 and x<15 else x)
# df_feature['p2_client_grade'].value_counts()

# %% [markdown]
# ## 特征工程

# %%
df_feature.loc[df_feature['p2_client_grade'].isna(), 'p2_client_grade'] = 0
df_feature.loc[df_feature['p2_client_grade']=='车主俱乐部-黑钻客户-2', 'p2_client_grade'] = 1
df_feature.loc[df_feature['p2_client_grade']=='车主俱乐部-钻石客户-2', 'p2_client_grade'] = 2
df_feature.loc[df_feature['p2_client_grade']=='车主俱乐部-铂金客户-2', 'p2_client_grade'] = 3
df_feature.loc[df_feature['p2_client_grade']=='车主俱乐部-黄金客户-2', 'p2_client_grade'] = 4
df_feature.loc[df_feature['p2_client_grade']=='车主俱乐部-白银客户-2', 'p2_client_grade'] = 5
df_feature.loc[df_feature['p2_client_grade']=='车主俱乐部-黄铜客户-2', 'p2_client_grade'] = 6
df_feature['p2_client_grade'] = df_feature['p2_client_grade'].astype('int')

# %%
df_feature['make_cn_cartype'] = df_feature['make_cn'].str.replace('([A-Za-z0-9()-ⅡⅢ]+)', ' ')
df_feature['make_cn_cartype_0'] = df_feature['make_cn_cartype'].apply(lambda x: x.split(' ')[0])
df_feature['make_cn_cartype_1'] = df_feature['make_cn_cartype'].apply(lambda x: x.split(' ')[-1])
print(df_feature['make_cn'].nunique(), df_feature['make_cn_cartype'].nunique(), df_feature['make_cn_cartype_0'].nunique(), df_feature['make_cn_cartype_1'].nunique())
df_feature[['brand_cn', 'make_cn_cartype_0', 'make_cn_cartype_1']][:5]
# Out:
# 11615 1035 449 60
#   brand_cn make_cn_cartype_0 make_cn_cartype_1
# 0  长安福特马自达                福特                轿车
# 1     天津丰田                丰田                轿车
# 2     长城汽车                长城               旅行车
# 3     一汽大众                奥迪                轿车
# 4     上汽大众              大众汽车            多用途乘用车

# %%
# 老人或小孩家庭
df_feature['p2_is_child_old_family'] = '否'
df_feature['p2_is_child_old_family']=np.where((df_feature['p2_is_child_under_15_family'] == '是') | (df_feature['p2_is_adult_over_55_family'] == '是'),'是',df_feature['p2_is_child_old_family'])
df_feature['p2_is_child_old_family'].value_counts()
# Out:
# 否    656986
# 是    107407
# Name: p2_is_child_old_family, dtype: int64

# %%
df_feature['personas'] = df_feature['p1_gender'].astype(str)+'_'+df_feature['p2_marital_status'].astype(str)+'_'+df_feature['f1_child_flag'].astype(str)+'_'+\
                        df_feature['f2_posses_house_flag'].astype(str)+'_'+df_feature['w1_pc_wx_use_flag'].astype(str)+'_'+df_feature['p1_is_bank_eff'].astype(str)
df_feature['xz_xb_co_15_55'] = df_feature['xz'].astype(str)+'_'+df_feature['xb'].astype(str)+'_'+df_feature['change_owner'].astype(str)+'_'+\
                        df_feature['p2_is_child_under_15_family'].astype(str)+'_'+df_feature['p2_is_adult_over_55_family'].astype(str)
df_feature['personas_cno_count'] = df_feature.groupby('personas')['client_no'].transform('count') 
# df_feature['xz_xb_co_15_55_cno_count'] = df_feature.groupby('xz_xb_co_15_55')['client_no'].transform('count')

# %%
df_feature['regdays'] = (pd.to_datetime('2021-1-31') - pd.to_datetime(df_feature['regdate'])) / pd.Timedelta(days=1)
df_feature['npremly_car_value_ratio'] = df_feature['nprem_ly'] / df_feature['newvalue']
df_feature['p3_service_use_ratio'] = df_feature['p3_service_use_cnt'] / df_feature['p1_service_offer_cnt']
df_feature['car_housing_value_ratio'] = df_feature['newvalue'] / df_feature['f2_cust_housing_price_total']
# df_feature.head()

# %%
df_feature['od_ratio'] = df_feature['nprem_od'] / df_feature['si_od']
df_feature['tp_ratio'] = df_feature['nprem_tp'] / df_feature['si_tp']
df_feature['bt_ratio'] = df_feature['nprem_bt'] / df_feature['si_bt'] # just so so
df_feature['vld_ratio'] = df_feature['nprem_vld'] / df_feature['si_vld']
df_feature['vlp_ratio'] = df_feature['nprem_vlp'] / df_feature['si_vlp']
df_feature['od_tp_ratio_2ord'] = df_feature['od_ratio'] / df_feature['tp_ratio']
df_feature['od_tp_ratio_2diff'] = df_feature['od_ratio'] - df_feature['tp_ratio']

df_feature['nprem_tot'] = df_feature['nprem_od'] + df_feature['nprem_tp'] + df_feature['nprem_bt'] + df_feature['nprem_vld'] + df_feature['nprem_vlp']
df_feature['nprem_od_percent'] = df_feature['nprem_od'] / df_feature['nprem_tot']
df_feature['nprem_tp_percent'] = df_feature['nprem_tp'] / df_feature['nprem_tot']
df_feature['nprem_odtp_percent_diff'] = df_feature['nprem_od_percent'] - df_feature['nprem_tp_percent']
df_feature['nprem_odtp_percent_add'] = (df_feature['nprem_od'] + df_feature['nprem_tp']) / df_feature['nprem_tot']

df_feature['nprem_20diff'] = df_feature['nprem_tot'] - df_feature['suiche_nonauto_nprem_20']
df_feature['nprem_20ratio'] = df_feature['nprem_tot'] / df_feature['suiche_nonauto_nprem_20']
df_feature['nprem_lydiff'] = df_feature['nprem_tot'] - df_feature['nprem_ly']
df_feature['nprem_lyratio'] = df_feature['nprem_tot'] / df_feature['nprem_ly']
# df_feature['20_lydiff'] = df_feature['suiche_nonauto_nprem_20'] - df_feature['nprem_ly']
# df_feature['20_lyratio'] = df_feature['suiche_nonauto_nprem_20'] / df_feature['nprem_ly']

df_feature['npremtot_car_value_ratio'] = df_feature['nprem_tot'] / df_feature['newvalue']
df_feature['npremtot_housing_value_ratio'] = df_feature['nprem_tot'] / df_feature['f2_cust_housing_price_total']

# %%
df_feature['suiche_nonauto_nprem_20_ydiff'] = df_feature['suiche_nonauto_nprem_20'] - df_feature['suiche_nonauto_nprem_19']
df_feature['suiche_nonauto_nprem_19_2ydiff'] = df_feature['suiche_nonauto_nprem_19'] - df_feature['suiche_nonauto_nprem_17']
df_feature['suiche_nonauto_nprem_17_ydiff'] = df_feature['suiche_nonauto_nprem_17'] - df_feature['suiche_nonauto_nprem_16']
df_feature['suiche_nonauto_nprem_20_yratio'] = df_feature['suiche_nonauto_nprem_20'] / df_feature['suiche_nonauto_nprem_19']
df_feature['suiche_nonauto_nprem_19_2yratio'] = df_feature['suiche_nonauto_nprem_19'] / df_feature['suiche_nonauto_nprem_17']
df_feature['suiche_nonauto_nprem_17_yratio'] = df_feature['suiche_nonauto_nprem_17'] / df_feature['suiche_nonauto_nprem_16']
df_feature['suiche_nonauto_nprem_20_19_yratio_2ord'] = df_feature['suiche_nonauto_nprem_20_yratio'] / df_feature['suiche_nonauto_nprem_19_2yratio']
df_feature['suiche_nonauto_nprem_20_17_yratio_2ord'] = df_feature['suiche_nonauto_nprem_20_yratio'] / df_feature['suiche_nonauto_nprem_17_yratio']

df_feature['suiche_nonauto_nprem_20_ratio'] = df_feature['suiche_nonauto_amount_20'] / df_feature['suiche_nonauto_nprem_20']
df_feature['suiche_nonauto_nprem_19_ratio'] = df_feature['suiche_nonauto_amount_19'] / df_feature['suiche_nonauto_nprem_19']
# df_feature['suiche_nonauto_nprem_18_ratio'] = df_feature['suiche_nonauto_amount_18'] / df_feature['suiche_nonauto_nprem_18'] #该年数据有异常
df_feature['suiche_nonauto_nprem_17_ratio'] = df_feature['suiche_nonauto_amount_17'] / df_feature['suiche_nonauto_nprem_17']
df_feature['suiche_nonauto_nprem_20_19_ratio_2diff'] = df_feature['suiche_nonauto_nprem_20_ratio'] - df_feature['suiche_nonauto_nprem_19_ratio']
df_feature['suiche_nonauto_nprem_20_19_ratio_2ord'] = df_feature['suiche_nonauto_nprem_20_ratio'] / df_feature['suiche_nonauto_nprem_19_ratio']
# df_feature['suiche_nonauto_nprem_19_17_ratio_2diff'] = df_feature['suiche_nonauto_nprem_19_ratio'] - df_feature['suiche_nonauto_nprem_17_ratio']
# df_feature['suiche_nonauto_nprem_19_17_ratio_2ord'] = df_feature['suiche_nonauto_nprem_19_ratio'] / df_feature['suiche_nonauto_nprem_17_ratio']
# df_feature['suiche_nonauto_nprem_20_17_ratio_3ord'] = df_feature['suiche_nonauto_nprem_20_19_ratio_2ord'] / df_feature['suiche_nonauto_nprem_19_17_ratio_2ord']
# df_feature['suiche_nonauto_nprem_20_17_ratio_3diff'] = df_feature['suiche_nonauto_nprem_20_19_ratio_2diff'] - df_feature['suiche_nonauto_nprem_19_17_ratio_2diff']

df_feature['active_7_30_ratio'] = (df_feature['active_7'] / 7) / (df_feature['active_30'] / 30) # just so so
df_feature['active_30_90_ratio'] = (df_feature['active_30'] / 30) / (df_feature['active_90'] / 90)
df_feature['active_30_90_diff'] = (df_feature['active_30'] / 30) - (df_feature['active_90'] / 90)
df_feature['active_30_365_ratio'] = (df_feature['active_30'] / 30) / (df_feature['active_365'] / 365)
df_feature['active_30_365_diff'] = (df_feature['active_30'] / 30) - (df_feature['active_365'] / 365)
df_feature['active_90_365_ratio'] = (df_feature['active_90'] / 90) / (df_feature['active_365'] / 365)
df_feature['active_90_365_diff'] = (df_feature['active_90'] / 90) - (df_feature['active_365'] / 365)

# %%
# 计数 count编码
count_fea_list = [['p1_census_register'], ['trademark_cn'], ['brand_cn'], ['series'], ['capab'], ['make_cn'], ['make_cn_cartype'], ['make_cn_cartype_0'], ['make_cn_cartype_1']]
count_fea_list += [['tp_ratio'], ['p1_age'], ['service_score_available'], ['nprem_tp'], ['suiche_nonauto_amount_20'], ['suiche_nonauto_amount_19'], ['nprem_ly'], ['p1_prior_days_to_insure']]
count_fea_list += [['personas'], ['xz_xb_co_15_55']]

for f in count_fea_list:
    df_temp = df_feature.groupby(f).size().reset_index()
    df_temp.columns = f + ['{}_count'.format('_'.join(f))]
    df_feature = df_feature.merge(df_temp, how='left')
    # 等价写法
    # df_feature[f + '_count'] = df_feature[f].map(df_feature[f].value_counts())

# %%
df_feature['birth_month'] = df_feature['birth_month'].apply(lambda x: int(x[:-1]) if type(x) != float else 0)
df_feature['reg_year'] = df_feature['regdate'].apply(lambda x: int(x[:4]) if type(x) != float else 0)
df_feature['reg_month'] = df_feature['regdate'].apply(lambda x: int(x[5:7]) if type(x) != float else 0)
df_feature['reg_day'] = df_feature['regdate'].apply(lambda x: int(x[8:9]) if type(x) != float else 0)

# %%
df_feature[~df_feature['y1_is_purchase'].isnull()].head()
# Out:
#                   client_no  dpt  xz  xb  \
# 0  5gDljzjQ61m/QeU2tZBgDA==  217  商交  主全
# 1  qTsiFUfrw8gwVOM+LftPvA==  217  商交  主全
# 2  vfTADBw3uqyLukTz5juO0g==  217  商交  主全
# 3  zP5cmQ2nwzLbvocQPmf2YA==  217  商交  主全
# 4  +ruD5NLealUAfMZPQd6LEw==  217  单交  单交
#
#                                           carid  nprem_ly    ncd_ly  newvalue  \
# 0  WY4N+MOjfIx8wJ3j6GhlA4qEfL71brEUkqbB0SSdqkI=    1391.0  0.600098     88900
# 1  DXMuODygH0ddFea7SIoAOhF4134Bx4TPvkkPi6WCdzU=    3740.0  1.000000    303000
# 2  waWCEYZJqj9PYxFdVeVLkpCNf/n0BdXPFi1iHlk0WWk=    1454.0  0.600098    132800
# 3  nyRm/VviYGDpy2errRWE206SaYkVuqeclusAtXEU9v8=    3526.0  0.850098    316800
# 4  LacSDMaoqD0AJRqCeYaGUu343r4NQiVuiFc9hyjLcMI=     522.5       NaN    247800
#
#    bi_renewal_year  clmnum              regdate trademark_cn brand_cn  \
# 0                6       0  2010-02-09 00:00:00           福特  长安福特马自达
# 1                6       0  2007-02-02 00:00:00           丰田     天津丰田
# 2                6       0  2007-01-01 00:00:00           长城     长城汽车
# 3                5       2  2015-02-09 00:00:00           奥迪     一汽大众
# 4                3       0  2017-12-12 00:00:00           大众     上汽大众
#
#                 make_cn series     capab  seats use_type change_owner  \
# 0          福特CAF7152A轿车    嘉年华  1.498047      5      非营业        非过户投保
# 1      丰田TV7250RoyalA轿车     皇冠  2.496094      5      非营业        非过户投保
# 2       长城CC6460KM60旅行车     哈弗  2.771484      5      非营业        非过户投保
# 3       奥迪FV7201BACBG轿车     A6  1.984375      5      非营业        非过户投保
# 4  大众汽车SVW6474CED多用途乘用车     途观  1.797852      5      非营业        非过户投保
#
#    nprem_od     si_od  nprem_tp    si_tp  nprem_bt     si_bt  nprem_vld  \
# 0    379.00   24892.0   239.250  1000000     0.000       0.0   3.750000
# 1   1993.00   60600.0   505.500  1000000    72.375   60600.0   0.000000
# 2    434.75   26560.0   251.375  1000000     0.000       0.0   0.000000
# 3   1651.00  202752.0   381.000  1000000   141.625  202752.0  17.921875
# 4      0.00       0.0     0.000        0     0.000       0.0   0.000000
#
#    si_vld  nprem_vlp  si_vlp  p1_prior_days_to_insure  \
# 0   10000   9.507812   10000                     30.0
# 1       0   0.000000       0                     27.0
# 2       0   0.000000       0                     30.0
# 3   30000  45.468750   30000                     27.0
# 4       0   0.000000       0                      1.0
#
#    suiche_nonauto_nprem_20  suiche_nonauto_nprem_19  suiche_nonauto_nprem_18  \
# 0                      NaN                      NaN                      NaN
# 1               390.000000                  0.00000                      0.0
# 2               350.000000                  0.00000                      0.0
# 3                 9.898438                 19.90625                      0.0
# 4                 0.000000                  0.00000                      0.0
#
#    suiche_nonauto_nprem_17  suiche_nonauto_nprem_16  suiche_nonauto_amount_20  \
# 0                      NaN                      NaN                       NaN
# 1                    170.0                    170.0                 2795000.0
# 2                      0.0                      0.0                 1695000.0
# 3                    170.0                      0.0                 1000000.0
# 4                      0.0                      0.0                       0.0
#
#    suiche_nonauto_amount_19  suiche_nonauto_amount_18  \
# 0                       NaN                       NaN
# 1                       0.0                       0.0
# 2                       0.0                       0.0
# 3                 1000000.0                       0.0
# 4                       0.0                       0.0
#
#    suiche_nonauto_amount_17  suiche_nonauto_amount_16  num_notcar_claim  \
# 0                       NaN                       NaN               NaN
# 1                  120000.0                  120000.0               NaN
# 2                       0.0                       0.0               NaN
# 3                  120000.0                       0.0               NaN
# 4                       0.0                       0.0               NaN
#
#                   p1_gender  p1_age  \
# 0  jh4mxXNEalwumcCWUJdnBw==    56.0
# 1  jh4mxXNEalwumcCWUJdnBw==    52.0
# 2  jh4mxXNEalwumcCWUJdnBw==    55.0
# 3  jh4mxXNEalwumcCWUJdnBw==    47.0
# 4  yUh7960km3oydK6Km9rqRA==    52.0
#
#                              p1_census_register         p2_marital_status  \
# 0  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 1  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 2  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 3  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 4  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
#
#   f1_child_flag f2_posses_house_flag  f2_cust_housing_price_total  \
# 0             是                    是                        0.000
# 1             是                    是                        0.000
# 2             是                    是                      154.625
# 3             是                    是                      208.000
# 4             否                    是                        0.000
#
#    p2_client_grade w1_pc_wx_use_flag p1_is_bank_eff p2_is_enterprise_owner  \
# 0                2                 是              否                    NaN
# 1                2                 是              否                      是
# 2                2                 否              是                      否
# 3                2                 是              是                      是
# 4                2                 是              否                      是
#
#   p2_is_smeowner  active_7  active_30  active_90  active_365  \
# 0            NaN       0.0        0.0        3.0        32.0
# 1              是       2.0        4.0       11.0        40.0
# 2              否       0.0        0.0        9.0        17.0
# 3              是       0.0        0.0        1.0         7.0
# 4              是       0.0        1.0       11.0        30.0
#
#   p2_is_child_under_15_family p2_is_adult_over_55_family  birth_month  \
# 0                           否                          是            6
# 1                           否                          否            9
# 2                           否                          否            2
# 3                           否                          否            7
# 4                           否                          否           11
#
#    p1_service_offer_cnt  p3_service_use_cnt  dur_personal_insurance_90  \
# 0                   0.0                 0.0                        NaN
# 1                   0.0                 0.0                        NaN
# 2                   0.0                 0.0                        NaN
# 3                   0.0                 0.0                   151786.0
# 4                   0.0                 0.0                        NaN
#
#    service_score_available  y1_is_purchase  flag make_cn_cartype  \
# 0                      0.0             0.0     0           福特 轿车
# 1                     10.0             1.0     0           丰田 轿车
# 2                     16.0             1.0     0          长城 旅行车
# 3                      0.0             1.0     0           奥迪 轿车
# 4                      1.0             1.0     0     大众汽车 多用途乘用车
#
#   make_cn_cartype_0 make_cn_cartype_1 p2_is_child_old_family  \
# 0                福特                轿车                      是
# 1                丰田                轿车                      否
# 2                长城               旅行车                      否
# 3                奥迪                轿车                      否
# 4              大众汽车            多用途乘用车                      否
#
#                                             personas   xz_xb_co_15_55  \
# 0  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_是
# 1  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_否
# 2  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_否
# 3  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_否
# 4  yUh7960km3oydK6Km9rqRA==_eNP+WqbTmmD3bj49nIcSe...  单交_单交_非过户投保_否_否
#
#    personas_cno_count  regdays  npremly_car_value_ratio  p3_service_use_ratio  \
# 0               12800   4009.0                 0.015647                   NaN
# 1               12800   5112.0                 0.012343                   NaN
# 2                4143   5144.0                 0.010949                   NaN
# 3                6513   2183.0                 0.011130                   NaN
# 4                8621   1146.0                 0.002109                   NaN
#
#    car_housing_value_ratio  od_ratio  tp_ratio  bt_ratio  vld_ratio  \
# 0                      inf  0.015226  0.000239       NaN   0.000375
# 1                      inf  0.032888  0.000505  0.001194        NaN
# 2               858.852061  0.016369  0.000251       NaN        NaN
# 3              1523.076923  0.008143  0.000381  0.000699   0.000597
# 4                      inf       NaN       NaN       NaN        NaN
#
#    vlp_ratio  od_tp_ratio_2ord  od_tp_ratio_2diff  nprem_tot  \
# 0   0.000951         63.639605           0.014987      631.5
# 1        NaN         65.059922           0.032382     2570.0
# 2        NaN         65.116259           0.016117      686.0
# 3   0.001516         21.372580           0.007762     2238.0
# 4        NaN               NaN                NaN        0.0
#
#    nprem_od_percent  nprem_tp_percent  nprem_odtp_percent_diff  \
# 0          0.600098          0.378906                 0.221191
# 1          0.775391          0.196655                 0.578613
# 2          0.633789          0.366455                 0.267334
# 3          0.737793          0.170288                 0.567383
# 4               NaN               NaN                      NaN
#
#    nprem_odtp_percent_add  nprem_20diff  nprem_20ratio  nprem_lydiff  \
# 0                0.978516           NaN            NaN        -759.5
# 1                0.972168        2180.0       6.589844       -1170.0
# 2                1.000000         336.0       1.959961        -768.0
# 3                0.907715        2228.0     226.125000       -1288.0
# 4                     NaN           0.0            NaN        -522.5
#
#    nprem_lyratio  npremtot_car_value_ratio  npremtot_housing_value_ratio  \
# 0       0.454102                  0.007103                           inf
# 1       0.687012                  0.008482                           inf
# 2       0.471924                  0.005166                      4.437500
# 3       0.634766                  0.007064                     10.757812
# 4       0.000000                  0.000000                           NaN
#
#    suiche_nonauto_nprem_20_ydiff  suiche_nonauto_nprem_19_2ydiff  \
# 0                            NaN                             NaN
# 1                     390.000000                        -170.000
# 2                     350.000000                           0.000
# 3                     -10.007812                        -150.125
# 4                       0.000000                           0.000
#
#    suiche_nonauto_nprem_17_ydiff  suiche_nonauto_nprem_20_yratio  \
# 0                            NaN                             NaN
# 1                            0.0                             inf
# 2                            0.0                             inf
# 3                          170.0                        0.497314
# 4                            0.0                             NaN
#
#    suiche_nonauto_nprem_19_2yratio  suiche_nonauto_nprem_17_yratio  \
# 0                              NaN                             NaN
# 1                         0.000000                             1.0
# 2                              NaN                             NaN
# 3                         0.117065                             inf
# 4                              NaN                             NaN
#
#    suiche_nonauto_nprem_20_19_yratio_2ord  \
# 0                                     NaN
# 1                                     inf
# 2                                     NaN
# 3                                    4.25
# 4                                     NaN
#
#    suiche_nonauto_nprem_20_17_yratio_2ord  suiche_nonauto_nprem_20_ratio  \
# 0                                     NaN                            NaN
# 1                                     inf                    7166.666504
# 2                                     NaN                    4842.856934
# 3                                     0.0                  101026.046875
# 4                                     NaN                            NaN
#
#    suiche_nonauto_nprem_19_ratio  suiche_nonauto_nprem_17_ratio  \
# 0                            NaN                            NaN
# 1                            NaN                     705.882324
# 2                            NaN                            NaN
# 3                   50235.480469                     705.882324
# 4                            NaN                            NaN
#
#    suiche_nonauto_nprem_20_19_ratio_2diff  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                            50790.566406
# 4                                     NaN
#
#    suiche_nonauto_nprem_20_19_ratio_2ord  active_7_30_ratio  \
# 0                                    NaN                NaN
# 1                                    NaN           2.142578
# 2                                    NaN                NaN
# 3                                2.01105                NaN
# 4                                    NaN           0.000000
#
#    active_30_90_ratio  active_30_90_diff  active_30_365_ratio  \
# 0            0.000000          -0.033325             0.000000
# 1            1.090820           0.011108             1.216370
# 2            0.000000          -0.099976             0.000000
# 3            0.000000          -0.011108             0.000000
# 4            0.272705          -0.088867             0.405457
#
#    active_30_365_diff  active_90_365_ratio  active_90_365_diff  \
# 0           -0.087671             0.380116           -0.054346
# 1            0.023712             1.115005            0.012603
# 2           -0.046575             2.146535            0.053400
# 3           -0.019178             0.579224           -0.008070
# 4           -0.048867             1.486674            0.040001
#
#    p1_census_register_count  trademark_cn_count  brand_cn_count  series_count  \
# 0                    6193.0               29781           15325        2014.0
# 1                    6193.0               40075           21400        1203.0
# 2                    6193.0               25550           25842       20960.0
# 3                    6193.0               12178           53772        3437.0
# 4                    6193.0               96796           10607        7750.0
#
#    capab_count  make_cn_count  make_cn_cartype_count  make_cn_cartype_0_count  \
# 0        45294             60                   7207                     8583
# 1         5192            165                  29924                    38719
# 2          981              3                   3337                    11440
# 3        15475            264                   8255                    12178
# 4        38063            523                   9571                    38524
#
#    make_cn_cartype_1_count  tp_ratio_count  p1_age_count  \
# 0                   518484           361.0        9339.0
# 1                   518484           526.0       15440.0
# 2                     6702           932.0       10131.0
# 3                   518484            27.0       21338.0
# 4                   158001             NaN       15440.0
#
#    service_score_available_count  nprem_tp_count  \
# 0                       345003.0             363
# 1                        16106.0              20
# 2                         2120.0             936
# 3                       345003.0              20
# 4                         8673.0           96729
#
#    suiche_nonauto_amount_20_count  suiche_nonauto_amount_19_count  \
# 0                             NaN                             NaN
# 1                         21152.0                        293955.0
# 2                         18735.0                        293955.0
# 3                         85566.0                         52519.0
# 4                        216811.0                        293955.0
#
#    nprem_ly_count  p1_prior_days_to_insure_count  personas_count  \
# 0             123                       130634.0           12800
# 1             258                        17549.0           12800
# 2              64                       130634.0            4143
# 3             188                        17549.0            6513
# 4             137                        55995.0            8621
#
#    xz_xb_co_15_55_count  reg_year  reg_month  reg_day
# 0                 50781      2010          2        0
# 1                418644      2007          2        0
# 2                418644      2007          1        0
# 3                418644      2015          2        0
# 4                 76268      2017         12        1

# %%
# groupby feature
def group_fea(df,key,target):
    tmp = df.groupby(key, as_index=False)[target].agg({
        key+target + '_nunique': 'nunique',
    }).reset_index()
    del tmp['index']
    print("**************************{}**************************".format(target))
    return tmp

feature_key = ['dpt']
feature_target = ['trademark_cn', 'suiche_nonauto_amount_20','service_score_available']
for key in tqdm(feature_key):
    for target in feature_target:
        tmp = group_fea(df_feature,key,target)
        df_feature = df_feature.merge(tmp,on=key,how='left')
        
# tmp = group_fea(df,'spread_app_id','task_id')
# df = df.merge(tmp,on='spread_app_id',how='left')
del tmp
gc.collect()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# **************************trademark_cn**************************
# **************************suiche_nonauto_amount_20**************************
# **************************service_score_available**************************
# 100%|██████████| 1/1 [00:08<00:00,  8.43s/it]
# 0

# %%
# dpt 统计数值类特征的均值
num_fea_list = ['service_score_available', 'dur_personal_insurance_90']
num_fea_list += ['active_365','ncd_ly', 'bi_renewal_year', 'clmnum', 'seats']
num_fea_list += ['regdays', 'od_ratio', 'p2_client_grade', 'od_tp_ratio_2ord', 'nprem_lyratio']
num_fea_list += ['bi_renewal_year', 'nprem_lyratio', 'si_tp', 'suiche_nonauto_nprem_20_ydiff']
for col in num_fea_list:
    df_feature[f'dpt{col}_mean'] = df_feature.groupby('dpt')[col].transform('mean')

del num_fea_list
# personas,  统计数值类特征的均值
num_fea_list = ['active_365', 'service_score_available', 'dur_personal_insurance_90', 'f2_cust_housing_price_total', 'suiche_nonauto_nprem_20_ydiff']
num_fea_list += ['regdays', 'tp_ratio', 'od_ratio', 'p2_client_grade', 'active_90_365_ratio', 'nprem_ly', 'ncd_ly', 'si_tp', 'suiche_nonauto_nprem_20_ydiff']
num_fea_list += ['od_tp_ratio_2ord', 'nprem_lyratio', 'newvalue', 'bi_renewal_year', 'clmnum', 'capab', 'seats', 'p2_client_grade']
for col in num_fea_list:
    df_feature['personas_{}_mean'.format(col)] = df_feature.groupby('personas')[col].transform('mean')

# %%
# feature = pd.DataFrame()
# to_group = [['suiche_nonauto_nprem_20']]
# to_inter = ['p1_prior_days_to_insure']
# to_calc = [
#     'mean',
#     'std',
#     'nunique',
# ]

# for i in tqdm(to_group):
#     for j in to_inter:
#         for k in to_calc:
#             feature["STAT_{}_{}_{}".format("_".join(i),j,k)] = df_feature[i + [j]].groupby(i)[j].transform(k)
            
# print(feature.shape)
# feature.reset_index(drop=True, inplace=True)
# df_feature[feature.columns] = feature
# del feature
# gc.collect()
# df_feature.shape

# %%
for agg in ['mean']:
    df_feature[f'dpt_ncd_ly_p1_prior_days_to_insure_2ord{agg}'] = df_feature.groupby(['dpt', 'ncd_ly'])['p1_prior_days_to_insure'].transform(agg)
    df_feature[f'dpt_ncd_ly_active_90_365_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'ncd_ly'])['active_90_365_ratio'].transform(agg)
    df_feature[f'dpt_ncd_ly_tp_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'ncd_ly'])['tp_ratio'].transform(agg)
    df_feature[f'dpt_ncd_ly_suiche_nonauto_nprem_20_ydiff_2ord{agg}'] = df_feature.groupby(['dpt', 'ncd_ly'])['suiche_nonauto_nprem_20_ydiff'].transform(agg)
    df_feature[f'dpt_ncd_ly_suiche_nonauto_nprem_20_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'ncd_ly'])['suiche_nonauto_nprem_20_ratio'].transform(agg)

    df_feature[f'dpt_p1_census_register_active_90_365_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['active_90_365_ratio'].transform(agg)
    df_feature[f'dpt_p1_census_register_p1_prior_days_to_insure_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['p1_prior_days_to_insure'].transform(agg)
    df_feature[f'dpt_p1_census_register_tp_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['tp_ratio'].transform(agg)
    df_feature[f'dpt_p1_census_register_regdays_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['regdays'].transform(agg)
    df_feature[f'dpt_p1_census_register_ncd_ly_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['ncd_ly'].transform(agg)
    df_feature[f'dpt_p1_census_register_suiche_nonauto_nprem_20_ydiff_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['suiche_nonauto_nprem_20_ydiff'].transform(agg)
    df_feature[f'dpt_p1_census_register_suiche_nonauto_nprem_20_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'p1_census_register'])['suiche_nonauto_nprem_20_ratio'].transform(agg)

    df_feature[f'dpt_p2_client_grade_active_90_365_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['active_90_365_ratio'].transform(agg)
    df_feature[f'dpt_p2_client_grade_p1_prior_days_to_insure_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['p1_prior_days_to_insure'].transform(agg)
    df_feature[f'dpt_p2_client_grade_tp_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['tp_ratio'].transform(agg)
    df_feature[f'dpt_p2_client_grade_regdays_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['regdays'].transform(agg)
    df_feature[f'dpt_p2_client_grade_ncd_ly_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['ncd_ly'].transform(agg)
    df_feature[f'dpt_p2_client_grade_suiche_nonauto_nprem_20_ydiff_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['suiche_nonauto_nprem_20_ydiff'].transform(agg)
    df_feature[f'dpt_p2_client_grade_suiche_nonauto_nprem_20_ratio_2ord{agg}'] = df_feature.groupby(['dpt', 'p2_client_grade'])['suiche_nonauto_nprem_20_ratio'].transform(agg)

# %%
# 5折交叉 目标编码
df_train = df_feature[df_feature['flag']==0]
df_train = df_train.reset_index(drop=True)
df_test = df_feature[df_feature['flag']==2]
print(df_train.shape, df_test.shape)

def n_fold_target_encoding(train_df,test_df,label='label',n=5,enc_list=[],functions=['mean']):
    skf = StratifiedKFold(n_splits=n, shuffle=True, random_state=seed)
    for f in tqdm(enc_list):
        for func in functions:
            train_df[f + f'_target_enc_{func}'] = 0
            test_df[f + f'_target_enc_{func}'] = 0
            for i, (trn_idx, val_idx) in enumerate(skf.split(train_df, train_df[label])):
                trn_x = train_df[[f, label]].iloc[trn_idx].reset_index(drop=True)
                val_x = train_df[[f]].iloc[val_idx].reset_index(drop=True)
                enc_df = trn_x.groupby(f, as_index=False)[label].agg({f + f'_target_enc_{func}': func})
                val_x = val_x.merge(enc_df, on=f, how='left')
                test_x = test_df[[f]].merge(enc_df, on=f, how='left')
                val_x[f + f'_target_enc_{func}'] = val_x[f + f'_target_enc_{func}'].fillna(train_df[label].agg(func))
                test_x[f + f'_target_enc_{func}'] = test_x[f + f'_target_enc_{func}'].fillna(train_df[label].agg(func))
                train_df.loc[val_idx, f + f'_target_enc_{func}'] = val_x[f + f'_target_enc_{func}'].values
                test_df[f + f'_target_enc_{func}'] += test_x[f + f'_target_enc_{func}'].values / skf.n_splits
                del(trn_x)
                del(val_x)
                del(enc_df)
                gc.collect()
    return train_df,test_df

target_enc_list = ['dpt', 'make_cn_cartype', 'trademark_cn', 'brand_cn', 'series', 'capab', 'ncd_ly', 'nprem_ly', 'make_cn_count']
target_enc_list += ['tp_ratio', 'p1_census_register', 'p2_client_grade', 'active_90_365_ratio', 'active_30_365_ratio', 'service_score_available']
target_enc_list += ['suiche_nonauto_nprem_19_ratio', 'suiche_nonauto_nprem_20_ratio', 'active_90_365_diff']
target_enc_list += ['nprem_lyratio', 'nprem_20ratio', 'personas', 'regdays', 'p1_prior_days_to_insure']
target_enc_list += ['make_cn_count','make_cn_cartype_count','make_cn_cartype_0_count', 'personas_count']

df_train, df_test = n_fold_target_encoding(df_train,df_test,label='y1_is_purchase',n=10,enc_list=target_enc_list,functions=['mean'])
df_feature = pd.concat([df_train, df_test], axis=0)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# (684283, 193) (80110, 193)
# 100%|██████████| 27/27 [03:27<00:00,  7.67s/it]

# %%
print(df_feature.shape)
df_feature.head()
# Out:
# (764393, 219)
#                   client_no  dpt  xz  xb  \
# 0  5gDljzjQ61m/QeU2tZBgDA==  217  商交  主全
# 1  qTsiFUfrw8gwVOM+LftPvA==  217  商交  主全
# 2  vfTADBw3uqyLukTz5juO0g==  217  商交  主全
# 3  zP5cmQ2nwzLbvocQPmf2YA==  217  商交  主全
# 4  +ruD5NLealUAfMZPQd6LEw==  217  单交  单交
#
#                                           carid  nprem_ly    ncd_ly  newvalue  \
# 0  WY4N+MOjfIx8wJ3j6GhlA4qEfL71brEUkqbB0SSdqkI=    1391.0  0.600098     88900
# 1  DXMuODygH0ddFea7SIoAOhF4134Bx4TPvkkPi6WCdzU=    3740.0  1.000000    303000
# 2  waWCEYZJqj9PYxFdVeVLkpCNf/n0BdXPFi1iHlk0WWk=    1454.0  0.600098    132800
# 3  nyRm/VviYGDpy2errRWE206SaYkVuqeclusAtXEU9v8=    3526.0  0.850098    316800
# 4  LacSDMaoqD0AJRqCeYaGUu343r4NQiVuiFc9hyjLcMI=     522.5       NaN    247800
#
#    bi_renewal_year  clmnum              regdate trademark_cn brand_cn  \
# 0                6       0  2010-02-09 00:00:00           福特  长安福特马自达
# 1                6       0  2007-02-02 00:00:00           丰田     天津丰田
# 2                6       0  2007-01-01 00:00:00           长城     长城汽车
# 3                5       2  2015-02-09 00:00:00           奥迪     一汽大众
# 4                3       0  2017-12-12 00:00:00           大众     上汽大众
#
#                 make_cn series     capab  seats use_type change_owner  \
# 0          福特CAF7152A轿车    嘉年华  1.498047      5      非营业        非过户投保
# 1      丰田TV7250RoyalA轿车     皇冠  2.496094      5      非营业        非过户投保
# 2       长城CC6460KM60旅行车     哈弗  2.771484      5      非营业        非过户投保
# 3       奥迪FV7201BACBG轿车     A6  1.984375      5      非营业        非过户投保
# 4  大众汽车SVW6474CED多用途乘用车     途观  1.797852      5      非营业        非过户投保
#
#    nprem_od     si_od  nprem_tp    si_tp  nprem_bt     si_bt  nprem_vld  \
# 0    379.00   24892.0   239.250  1000000     0.000       0.0   3.750000
# 1   1993.00   60600.0   505.500  1000000    72.375   60600.0   0.000000
# 2    434.75   26560.0   251.375  1000000     0.000       0.0   0.000000
# 3   1651.00  202752.0   381.000  1000000   141.625  202752.0  17.921875
# 4      0.00       0.0     0.000        0     0.000       0.0   0.000000
#
#    si_vld  nprem_vlp  si_vlp  p1_prior_days_to_insure  \
# 0   10000   9.507812   10000                     30.0
# 1       0   0.000000       0                     27.0
# 2       0   0.000000       0                     30.0
# 3   30000  45.468750   30000                     27.0
# 4       0   0.000000       0                      1.0
#
#    suiche_nonauto_nprem_20  suiche_nonauto_nprem_19  suiche_nonauto_nprem_18  \
# 0                      NaN                      NaN                      NaN
# 1               390.000000                  0.00000                      0.0
# 2               350.000000                  0.00000                      0.0
# 3                 9.898438                 19.90625                      0.0
# 4                 0.000000                  0.00000                      0.0
#
#    suiche_nonauto_nprem_17  suiche_nonauto_nprem_16  suiche_nonauto_amount_20  \
# 0                      NaN                      NaN                       NaN
# 1                    170.0                    170.0                 2795000.0
# 2                      0.0                      0.0                 1695000.0
# 3                    170.0                      0.0                 1000000.0
# 4                      0.0                      0.0                       0.0
#
#    suiche_nonauto_amount_19  suiche_nonauto_amount_18  \
# 0                       NaN                       NaN
# 1                       0.0                       0.0
# 2                       0.0                       0.0
# 3                 1000000.0                       0.0
# 4                       0.0                       0.0
#
#    suiche_nonauto_amount_17  suiche_nonauto_amount_16  num_notcar_claim  \
# 0                       NaN                       NaN               NaN
# 1                  120000.0                  120000.0               NaN
# 2                       0.0                       0.0               NaN
# 3                  120000.0                       0.0               NaN
# 4                       0.0                       0.0               NaN
#
#                   p1_gender  p1_age  \
# 0  jh4mxXNEalwumcCWUJdnBw==    56.0
# 1  jh4mxXNEalwumcCWUJdnBw==    52.0
# 2  jh4mxXNEalwumcCWUJdnBw==    55.0
# 3  jh4mxXNEalwumcCWUJdnBw==    47.0
# 4  yUh7960km3oydK6Km9rqRA==    52.0
#
#                              p1_census_register         p2_marital_status  \
# 0  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 1  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 2  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 3  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
# 4  Mk+Y/3ew22P1DY8uqPLGGCIFQPo4OFXgq8CuM+8YhMo=  eNP+WqbTmmD3bj49nIcSew==
#
#   f1_child_flag f2_posses_house_flag  f2_cust_housing_price_total  \
# 0             是                    是                        0.000
# 1             是                    是                        0.000
# 2             是                    是                      154.625
# 3             是                    是                      208.000
# 4             否                    是                        0.000
#
#    p2_client_grade w1_pc_wx_use_flag p1_is_bank_eff p2_is_enterprise_owner  \
# 0                2                 是              否                    NaN
# 1                2                 是              否                      是
# 2                2                 否              是                      否
# 3                2                 是              是                      是
# 4                2                 是              否                      是
#
#   p2_is_smeowner  active_7  active_30  active_90  active_365  \
# 0            NaN       0.0        0.0        3.0        32.0
# 1              是       2.0        4.0       11.0        40.0
# 2              否       0.0        0.0        9.0        17.0
# 3              是       0.0        0.0        1.0         7.0
# 4              是       0.0        1.0       11.0        30.0
#
#   p2_is_child_under_15_family p2_is_adult_over_55_family  birth_month  \
# 0                           否                          是            6
# 1                           否                          否            9
# 2                           否                          否            2
# 3                           否                          否            7
# 4                           否                          否           11
#
#    p1_service_offer_cnt  p3_service_use_cnt  dur_personal_insurance_90  \
# 0                   0.0                 0.0                        NaN
# 1                   0.0                 0.0                        NaN
# 2                   0.0                 0.0                        NaN
# 3                   0.0                 0.0                   151786.0
# 4                   0.0                 0.0                        NaN
#
#    service_score_available  y1_is_purchase  flag make_cn_cartype  \
# 0                      0.0             0.0     0           福特 轿车
# 1                     10.0             1.0     0           丰田 轿车
# 2                     16.0             1.0     0          长城 旅行车
# 3                      0.0             1.0     0           奥迪 轿车
# 4                      1.0             1.0     0     大众汽车 多用途乘用车
#
#   make_cn_cartype_0 make_cn_cartype_1 p2_is_child_old_family  \
# 0                福特                轿车                      是
# 1                丰田                轿车                      否
# 2                长城               旅行车                      否
# 3                奥迪                轿车                      否
# 4              大众汽车            多用途乘用车                      否
#
#                                             personas   xz_xb_co_15_55  \
# 0  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_是
# 1  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_否
# 2  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_否
# 3  jh4mxXNEalwumcCWUJdnBw==_eNP+WqbTmmD3bj49nIcSe...  商交_主全_非过户投保_否_否
# 4  yUh7960km3oydK6Km9rqRA==_eNP+WqbTmmD3bj49nIcSe...  单交_单交_非过户投保_否_否
#
#    personas_cno_count  regdays  npremly_car_value_ratio  p3_service_use_ratio  \
# 0               12800   4009.0                 0.015647                   NaN
# 1               12800   5112.0                 0.012343                   NaN
# 2                4143   5144.0                 0.010949                   NaN
# 3                6513   2183.0                 0.011130                   NaN
# 4                8621   1146.0                 0.002109                   NaN
#
#    car_housing_value_ratio  od_ratio  tp_ratio  bt_ratio  vld_ratio  \
# 0                      inf  0.015226  0.000239       NaN   0.000375
# 1                      inf  0.032888  0.000505  0.001194        NaN
# 2               858.852061  0.016369  0.000251       NaN        NaN
# 3              1523.076923  0.008143  0.000381  0.000699   0.000597
# 4                      inf       NaN       NaN       NaN        NaN
#
#    vlp_ratio  od_tp_ratio_2ord  od_tp_ratio_2diff  nprem_tot  \
# 0   0.000951         63.639605           0.014987      631.5
# 1        NaN         65.059922           0.032382     2570.0
# 2        NaN         65.116259           0.016117      686.0
# 3   0.001516         21.372580           0.007762     2238.0
# 4        NaN               NaN                NaN        0.0
#
#    nprem_od_percent  nprem_tp_percent  nprem_odtp_percent_diff  \
# 0          0.600098          0.378906                 0.221191
# 1          0.775391          0.196655                 0.578613
# 2          0.633789          0.366455                 0.267334
# 3          0.737793          0.170288                 0.567383
# 4               NaN               NaN                      NaN
#
#    nprem_odtp_percent_add  nprem_20diff  nprem_20ratio  nprem_lydiff  \
# 0                0.978516           NaN            NaN        -759.5
# 1                0.972168        2180.0       6.589844       -1170.0
# 2                1.000000         336.0       1.959961        -768.0
# 3                0.907715        2228.0     226.125000       -1288.0
# 4                     NaN           0.0            NaN        -522.5
#
#    nprem_lyratio  npremtot_car_value_ratio  npremtot_housing_value_ratio  \
# 0       0.454102                  0.007103                           inf
# 1       0.687012                  0.008482                           inf
# 2       0.471924                  0.005166                      4.437500
# 3       0.634766                  0.007064                     10.757812
# 4       0.000000                  0.000000                           NaN
#
#    suiche_nonauto_nprem_20_ydiff  suiche_nonauto_nprem_19_2ydiff  \
# 0                            NaN                             NaN
# 1                     390.000000                        -170.000
# 2                     350.000000                           0.000
# 3                     -10.007812                        -150.125
# 4                       0.000000                           0.000
#
#    suiche_nonauto_nprem_17_ydiff  suiche_nonauto_nprem_20_yratio  \
# 0                            NaN                             NaN
# 1                            0.0                             inf
# 2                            0.0                             inf
# 3                          170.0                        0.497314
# 4                            0.0                             NaN
#
#    suiche_nonauto_nprem_19_2yratio  suiche_nonauto_nprem_17_yratio  \
# 0                              NaN                             NaN
# 1                         0.000000                             1.0
# 2                              NaN                             NaN
# 3                         0.117065                             inf
# 4                              NaN                             NaN
#
#    suiche_nonauto_nprem_20_19_yratio_2ord  \
# 0                                     NaN
# 1                                     inf
# 2                                     NaN
# 3                                    4.25
# 4                                     NaN
#
#    suiche_nonauto_nprem_20_17_yratio_2ord  suiche_nonauto_nprem_20_ratio  \
# 0                                     NaN                            NaN
# 1                                     inf                    7166.666504
# 2                                     NaN                    4842.856934
# 3                                     0.0                  101026.046875
# 4                                     NaN                            NaN
#
#    suiche_nonauto_nprem_19_ratio  suiche_nonauto_nprem_17_ratio  \
# 0                            NaN                            NaN
# 1                            NaN                     705.882324
# 2                            NaN                            NaN
# 3                   50235.480469                     705.882324
# 4                            NaN                            NaN
#
#    suiche_nonauto_nprem_20_19_ratio_2diff  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                            50790.566406
# 4                                     NaN
#
#    suiche_nonauto_nprem_20_19_ratio_2ord  active_7_30_ratio  \
# 0                                    NaN                NaN
# 1                                    NaN           2.142578
# 2                                    NaN                NaN
# 3                                2.01105                NaN
# 4                                    NaN           0.000000
#
#    active_30_90_ratio  active_30_90_diff  active_30_365_ratio  \
# 0            0.000000          -0.033325             0.000000
# 1            1.090820           0.011108             1.216370
# 2            0.000000          -0.099976             0.000000
# 3            0.000000          -0.011108             0.000000
# 4            0.272705          -0.088867             0.405457
#
#    active_30_365_diff  active_90_365_ratio  active_90_365_diff  \
# 0           -0.087671             0.380116           -0.054346
# 1            0.023712             1.115005            0.012603
# 2           -0.046575             2.146535            0.053400
# 3           -0.019178             0.579224           -0.008070
# 4           -0.048867             1.486674            0.040001
#
#    p1_census_register_count  trademark_cn_count  brand_cn_count  series_count  \
# 0                    6193.0               29781           15325        2014.0
# 1                    6193.0               40075           21400        1203.0
# 2                    6193.0               25550           25842       20960.0
# 3                    6193.0               12178           53772        3437.0
# 4                    6193.0               96796           10607        7750.0
#
#    capab_count  make_cn_count  make_cn_cartype_count  make_cn_cartype_0_count  \
# 0        45294             60                   7207                     8583
# 1         5192            165                  29924                    38719
# 2          981              3                   3337                    11440
# 3        15475            264                   8255                    12178
# 4        38063            523                   9571                    38524
#
#    make_cn_cartype_1_count  tp_ratio_count  p1_age_count  \
# 0                   518484           361.0        9339.0
# 1                   518484           526.0       15440.0
# 2                     6702           932.0       10131.0
# 3                   518484            27.0       21338.0
# 4                   158001             NaN       15440.0
#
#    service_score_available_count  nprem_tp_count  \
# 0                       345003.0             363
# 1                        16106.0              20
# 2                         2120.0             936
# 3                       345003.0              20
# 4                         8673.0           96729
#
#    suiche_nonauto_amount_20_count  suiche_nonauto_amount_19_count  \
# 0                             NaN                             NaN
# 1                         21152.0                        293955.0
# 2                         18735.0                        293955.0
# 3                         85566.0                         52519.0
# 4                        216811.0                        293955.0
#
#    nprem_ly_count  p1_prior_days_to_insure_count  personas_count  \
# 0             123                       130634.0           12800
# 1             258                        17549.0           12800
# 2              64                       130634.0            4143
# 3             188                        17549.0            6513
# 4             137                        55995.0            8621
#
#    xz_xb_co_15_55_count  reg_year  reg_month  reg_day  \
# 0                 50781      2010          2        0
# 1                418644      2007          2        0
# 2                418644      2007          1        0
# 3                418644      2015          2        0
# 4                 76268      2017         12        1
#
#    dpttrademark_cn_nunique  dptsuiche_nonauto_amount_20_nunique  \
# 0                      113                                  243
# 1                      113                                  243
# 2                      113                                  243
# 3                      113                                  243
# 4                      113                                  243
#
#    dptservice_score_available_nunique  dptservice_score_available_mean  \
# 0                                3120                       764.579773
# 1                                3120                       764.579773
# 2                                3120                       764.579773
# 3                                3120                       764.579773
# 4                                3120                       764.579773
#
#    dptdur_personal_insurance_90_mean  dptactive_365_mean  dptncd_ly_mean  \
# 0                         69417.9375            33.78125        0.744629
# 1                         69417.9375            33.78125        0.744629
# 2                         69417.9375            33.78125        0.744629
# 3                         69417.9375            33.78125        0.744629
# 4                         69417.9375            33.78125        0.744629
#
#    dptbi_renewal_year_mean  dptclmnum_mean  dptseats_mean  dptregdays_mean  \
# 0                 3.249175        0.143442       5.290767      2426.453376
# 1                 3.249175        0.143442       5.290767      2426.453376
# 2                 3.249175        0.143442       5.290767      2426.453376
# 3                 3.249175        0.143442       5.290767      2426.453376
# 4                 3.249175        0.143442       5.290767      2426.453376
#
#    dptod_ratio_mean  dptp2_client_grade_mean  dptod_tp_ratio_2ord_mean  \
# 0          0.009034                 2.943542                 26.303626
# 1          0.009034                 2.943542                 26.303626
# 2          0.009034                 2.943542                 26.303626
# 3          0.009034                 2.943542                 26.303626
# 4          0.009034                 2.943542                 26.303626
#
#    dptnprem_lyratio_mean  dptsi_tp_mean  \
# 0                  0.375  808389.359836
# 1                  0.375  808389.359836
# 2                  0.375  808389.359836
# 3                  0.375  808389.359836
# 4                  0.375  808389.359836
#
#    dptsuiche_nonauto_nprem_20_ydiff_mean  personas_active_365_mean  \
# 0                                 38.625                 32.687500
# 1                                 38.625                 32.687500
# 2                                 38.625                 31.375000
# 3                                 38.625                 38.843750
# 4                                 38.625                 28.453125
#
#    personas_service_score_available_mean  \
# 0                            1053.029053
# 1                            1053.029053
# 2                            1187.225586
# 3                            1596.521973
# 4                             773.134460
#
#    personas_dur_personal_insurance_90_mean  \
# 0                            122923.820312
# 1                            122923.820312
# 2                            120779.351562
# 3                            143701.593750
# 4                             89221.382812
#
#    personas_f2_cust_housing_price_total_mean  \
# 0                                    90.5625
# 1                                    90.5625
# 2                                    83.3125
# 3                                    87.0000
# 4                                   122.5000
#
#    personas_suiche_nonauto_nprem_20_ydiff_mean  personas_regdays_mean  \
# 0                                     53.37500            2834.185703
# 1                                     53.37500            2834.185703
# 2                                     54.75000            2823.992276
# 3                                     71.37500            2848.344542
# 4                                     43.53125            2806.720218
#
#    personas_tp_ratio_mean  personas_od_ratio_mean  \
# 0                0.000984                0.017096
# 1                0.000984                0.017096
# 2                0.000998                0.016798
# 3                0.000976                0.016990
# 4                0.001058                0.017194
#
#    personas_p2_client_grade_mean  personas_active_90_365_ratio_mean  \
# 0                       2.531484                           1.774751
# 1                       2.531484                           1.774751
# 2                       2.520396                           1.717182
# 3                       2.407646                           1.668997
# 4                       2.607470                           1.835750
#
#    personas_nprem_ly_mean  personas_ncd_ly_mean  personas_si_tp_mean  \
# 0                  2610.0              0.701172        907765.625000
# 1                  2610.0              0.701172        907765.625000
# 2                  2868.0              0.737305        908484.190200
# 3                  2852.0              0.723145        932097.343774
# 4                  2732.0              0.707520        872004.407841
#
#    personas_od_tp_ratio_2ord_mean  personas_nprem_lyratio_mean  \
# 0                       20.663652                     0.536133
# 1                       20.663652                     0.536133
# 2                       19.949303                     0.534668
# 3                       20.273459                     0.545898
# 4                       19.193571                     0.548340
#
#    personas_newvalue_mean  personas_bi_renewal_year_mean  \
# 0           139255.363828                       3.774688
# 1           139255.363828                       3.774688
# 2           166271.649529                       3.624909
# 3           161642.198833                       3.717642
# 4           150723.386846                       3.742025
#
#    personas_clmnum_mean  personas_capab_mean  personas_seats_mean  \
# 0              0.130859             1.727539             5.314531
# 1              0.130859             1.727539             5.314531
# 2              0.186338             1.796875             5.331644
# 3              0.152618             1.791016             5.369876
# 4              0.138383             1.719727             5.132467
#
#    dpt_ncd_ly_p1_prior_days_to_insure_2ordmean  \
# 0                                    21.921875
# 1                                    17.718750
# 2                                    21.921875
# 3                                    18.296875
# 4                                          NaN
#
#    dpt_ncd_ly_active_90_365_ratio_2ordmean  dpt_ncd_ly_tp_ratio_2ordmean  \
# 0                                 1.518002                      0.000282
# 1                                 1.517112                      0.000494
# 2                                 1.518002                      0.000282
# 3                                 1.554707                      0.000406
# 4                                      NaN                           NaN
#
#    dpt_ncd_ly_suiche_nonauto_nprem_20_ydiff_2ordmean  \
# 0                                           57.34375
# 1                                           65.50000
# 2                                           57.34375
# 3                                           32.25000
# 4                                                NaN
#
#    dpt_ncd_ly_suiche_nonauto_nprem_20_ratio_2ordmean  \
# 0                                                inf
# 1                                                inf
# 2                                                inf
# 3                                       3.212491e+04
# 4                                                NaN
#
#    dpt_p1_census_register_active_90_365_ratio_2ordmean  \
# 0                                           1.567076
# 1                                           1.567076
# 2                                           1.567076
# 3                                           1.567076
# 4                                           1.567076
#
#    dpt_p1_census_register_p1_prior_days_to_insure_2ordmean  \
# 0                                          20.109375
# 1                                          20.109375
# 2                                          20.109375
# 3                                          20.109375
# 4                                          20.109375
#
#    dpt_p1_census_register_tp_ratio_2ordmean  \
# 0                                  0.000349
# 1                                  0.000349
# 2                                  0.000349
# 3                                  0.000349
# 4                                  0.000349
#
#    dpt_p1_census_register_regdays_2ordmean  \
# 0                               2610.02945
# 1                               2610.02945
# 2                               2610.02945
# 3                               2610.02945
# 4                               2610.02945
#
#    dpt_p1_census_register_ncd_ly_2ordmean  \
# 0                                0.745117
# 1                                0.745117
# 2                                0.745117
# 3                                0.745117
# 4                                0.745117
#
#    dpt_p1_census_register_suiche_nonauto_nprem_20_ydiff_2ordmean  \
# 0                                            36.6875
# 1                                            36.6875
# 2                                            36.6875
# 3                                            36.6875
# 4                                            36.6875
#
#    dpt_p1_census_register_suiche_nonauto_nprem_20_ratio_2ordmean  \
# 0                                       33300.691406
# 1                                       33300.691406
# 2                                       33300.691406
# 3                                       33300.691406
# 4                                       33300.691406
#
#    dpt_p2_client_grade_active_90_365_ratio_2ordmean  \
# 0                                          1.519506
# 1                                          1.519506
# 2                                          1.519506
# 3                                          1.519506
# 4                                          1.519506
#
#    dpt_p2_client_grade_p1_prior_days_to_insure_2ordmean  \
# 0                                          21.109375
# 1                                          21.109375
# 2                                          21.109375
# 3                                          21.109375
# 4                                          21.109375
#
#    dpt_p2_client_grade_tp_ratio_2ordmean  \
# 0                                0.00034
# 1                                0.00034
# 2                                0.00034
# 3                                0.00034
# 4                                0.00034
#
#    dpt_p2_client_grade_regdays_2ordmean  dpt_p2_client_grade_ncd_ly_2ordmean  \
# 0                           2719.242108                             0.706055
# 1                           2719.242108                             0.706055
# 2                           2719.242108                             0.706055
# 3                           2719.242108                             0.706055
# 4                           2719.242108                             0.706055
#
#    dpt_p2_client_grade_suiche_nonauto_nprem_20_ydiff_2ordmean  \
# 0                                           49.15625
# 1                                           49.15625
# 2                                           49.15625
# 3                                           49.15625
# 4                                           49.15625
#
#    dpt_p2_client_grade_suiche_nonauto_nprem_20_ratio_2ordmean  \
# 0                                                inf
# 1                                                inf
# 2                                                inf
# 3                                                inf
# 4                                                inf
#
#    dpt_target_enc_mean  make_cn_cartype_target_enc_mean  \
# 0             0.467285                         0.648926
# 1             0.467285                         0.640137
# 2             0.467285                         0.656250
# 3             0.470947                         0.583008
# 4             0.467285                         0.705566
#
#    trademark_cn_target_enc_mean  brand_cn_target_enc_mean  \
# 0                      0.641602                  0.610840
# 1                      0.645020                  0.641113
# 2                      0.683594                  0.682129
# 3                      0.593262                  0.653320
# 4                      0.664062                  0.689941
#
#    series_target_enc_mean  capab_target_enc_mean  ncd_ly_target_enc_mean  \
# 0                0.595215               0.641113                0.704590
# 1                0.631348               0.604004                0.634277
# 2                0.698730               0.590332                0.704590
# 3                0.590820               0.622070                0.673828
# 4                0.713867               0.668457                     NaN
#
#    nprem_ly_target_enc_mean  make_cn_count_target_enc_mean  \
# 0                  0.500000                       0.610840
# 1                  0.724609                       0.617676
# 2                  0.480713                       0.541992
# 3                  0.763184                       0.664551
# 4                  0.371582                       0.728027
#
#    tp_ratio_target_enc_mean  p1_census_register_target_enc_mean  \
# 0                  0.645508                            0.445801
# 1                  0.655762                            0.447021
# 2                  0.593262                            0.447021
# 3                  0.222168                            0.447998
# 4                       NaN                            0.445801
#
#    p2_client_grade_target_enc_mean  active_90_365_ratio_target_enc_mean  \
# 0                         0.670898                             0.632324
# 1                         0.670898                             0.633301
# 2                         0.670898                             0.668457
# 3                         0.670898                             0.581543
# 4                         0.670898                             0.637207
#
#    active_30_365_ratio_target_enc_mean  \
# 0                             0.590332
# 1                             0.671387
# 2                             0.590332
# 3                             0.589844
# 4                             0.615234
#
#    service_score_available_target_enc_mean  \
# 0                                 0.613770
# 1                                 0.629395
# 2                                 0.657715
# 3                                 0.613770
# 4                                 0.643555
#
#    suiche_nonauto_nprem_19_ratio_target_enc_mean  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                       0.523926
# 4                                            NaN
#
#    suiche_nonauto_nprem_20_ratio_target_enc_mean  \
# 0                                            NaN
# 1                                       0.856445
# 2                                       0.839355
# 3                                       0.417969
# 4                                            NaN
#
#    active_90_365_diff_target_enc_mean  nprem_lyratio_target_enc_mean  \
# 0                            0.635742                       0.472412
# 1                            0.649902                       0.709473
# 2                            0.667480                       0.549805
# 3                            0.576660                       0.735352
# 4                            0.636230                       0.265869
#
#    nprem_20ratio_target_enc_mean  personas_target_enc_mean  \
# 0                            NaN                  0.661133
# 1                       0.824219                  0.663574
# 2                       0.600098                  0.601074
# 3                       0.428467                  0.639648
# 4                            NaN                  0.658203
#
#    regdays_target_enc_mean  p1_prior_days_to_insure_target_enc_mean  \
# 0                 0.593750                                 0.741699
# 1                 0.526855                                 0.668457
# 2                 0.388672                                 0.741699
# 3                 0.686035                                 0.666016
# 4                 0.369629                                 0.438477
#
#    make_cn_cartype_count_target_enc_mean  \
# 0                               0.648926
# 1                               0.640137
# 2                               0.656250
# 3                               0.583008
# 4                               0.705566
#
#    make_cn_cartype_0_count_target_enc_mean  personas_count_target_enc_mean
# 0                                 0.652832                        0.661133
# 1                                 0.646484                        0.663574
# 2                                 0.644531                        0.601074
# 3                                 0.593262                        0.639648
# 4                                 0.693359                        0.658203

# %% [markdown]
# ## 模型训练

# %%
# for f in list(df_feature.select_dtypes('object')):
#     if f in ['carid', 'regdate']:
#         continue
#     le = LabelEncoder()
#     df_feature[f] = le.fit_transform(
#         df_feature[f].astype('str')).astype('int')

# %%
df_train = df_feature[df_feature['flag']==0]
df_test = df_feature[df_feature['flag']==2]
df_train = reduce_mem(df_train)
df_test = reduce_mem(df_test)
gc.collect()
# Out:
# -- Mem. usage decreased to 508.36 Mb (34.4% reduction),time spend:0.10 min
# -- Mem. usage decreased to 59.36 Mb (34.6% reduction),time spend:0.01 min
# 0

# %%
# print('开始储存train_label')
# train_label = pd.DataFrame()
# train_label['carid'] = df_train['carid']
# train_label['probability'] = df_train['y1_is_purchase'].values
# train_label.to_csv('train_label_'+str(seed), index = False)
# print(train_label.shape)
# train_label.head()

# %%
ycol = 'y1_is_purchase'
drop_fea_list = [ycol, 'regdate', 'carid', 'use_type', 'suiche_nonauto_nprem_18', 'suiche_nonauto_amount_18', 'client_no', 'num_notcar_claim', 'flag']
drop_fea_list += ['xz', 'xb', 'trademark_cn', 'brand_cn', 'make_cn', 'series', 'change_owner', 'p1_gender', 'p1_census_register', 'p2_marital_status', 'f1_child_flag', 'f2_posses_house_flag', 'w1_pc_wx_use_flag', 'p1_is_bank_eff', 'p2_is_enterprise_owner', 'p2_is_smeowner', 'p2_is_child_under_15_family', 'p2_is_adult_over_55_family', 'make_cn_cartype', 'make_cn_cartype_0', 'make_cn_cartype_1', 'p2_is_child_old_family', 'personas', 'xz_xb_co_15_55']
# drop_fea_list += ['si_od', 'si_tp', 'si_bt', 'si_vld', 'si_vlp'] # 线下下降三个万
feature_names = list(
    filter(lambda x: x not in drop_fea_list, df_train.columns))

model = lgb.LGBMClassifier(num_leaves=200,
                           max_depth=9,
                           learning_rate=0.03,
                           n_estimators=10000,
                        #    subsample=0.9,
                           feature_fraction=0.6,
                        #    lambda_l1=0.1,
                        #    lambda_l2=0.1,
                        #    min_child_weight=30,
                           bagging_fraction=0.9,
                        #    bagging_freq=5,
                           reg_alpha=0.5,
                           reg_lambda=0.5,
                           random_state=seed,
                           n_jobs=4,
                           metric=None)

oof =  np.zeros(len(df_train)) 
prediction = df_test[['carid']]
prediction['label'] = 0
df_importance_list = []

kfold = StratifiedKFold(n_splits=10, random_state=seed, shuffle=True)
for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(
        df_train[feature_names], df_train[ycol])):
    X_train = df_train.iloc[trn_idx][feature_names]
    Y_train = df_train.iloc[trn_idx][ycol]

    X_val = df_train.iloc[val_idx][feature_names]
    Y_val = df_train.iloc[val_idx][ycol]

    print('\nFold_{} Training ================================\n'.format(fold_id+1))

    lgb_model = model.fit(X_train,
                          Y_train,
                          eval_names=['valid'],
                          eval_set=[(X_val, Y_val)],
                          verbose=100,
                          eval_metric='auc',
                          early_stopping_rounds=50)

    pred_val = lgb_model.predict_proba(
        X_val, num_iteration=lgb_model.best_iteration_)[:, 1]
    oof[val_idx] = pred_val
    # df_oof = df_train.iloc[val_idx][[
    #     'carid', ycol]].copy()
    # df_oof['pred'] = pred_val
    # oof.append(df_oof)

    pred_test = lgb_model.predict_proba(
        df_test[feature_names], num_iteration=lgb_model.best_iteration_)[:, 1]
    prediction['label'] += pred_test / 10

    df_importance = pd.DataFrame({
        'column': feature_names,
        'importance': lgb_model.feature_importances_,
    })
    df_importance_list.append(df_importance)

    del lgb_model, pred_val, pred_test, X_train, Y_train, X_val, Y_val
    gc.collect()
# Out:
# Fold_1 Training ================================
#
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.895718	valid's binary_logloss: 0.378689
# [200]	valid's auc: 0.900844	valid's binary_logloss: 0.363595
# [300]	valid's auc: 0.90278	valid's binary_logloss: 0.359249
# [400]	valid's auc: 0.903765	valid's binary_logloss: 0.357214
# [500]	valid's auc: 0.904385	valid's binary_logloss: 0.355953
# [600]	valid's auc: 0.904646	valid's binary_logloss: 0.35536
# [700]	valid's auc: 0.904852	valid's binary_logloss: 0.354928
# [800]	valid's auc: 0.904938	valid's binary_logloss: 0.354649
# [900]	valid's auc: 0.905006	valid's binary_logloss: 0.354456
# [1000]	valid's auc: 0.905071	valid's binary_logloss: 0.354279
# [1100]	valid's auc: 0.905135	valid's binary_logloss: 0.354103
# [1200]	valid's auc: 0.905193	valid's binary_logloss: 0.353977
# [1300]	valid's auc: 0.905231	valid's binary_logloss: 0.353863
# Early stopping, best iteration is:
# [1283]	valid's auc: 0.905252	valid's binary_logloss: 0.353836
#
# Fold_2 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.893242	valid's binary_logloss: 0.381523
# [200]	valid's auc: 0.898097	valid's binary_logloss: 0.367127
# [300]	valid's auc: 0.900206	valid's binary_logloss: 0.362775
# [400]	valid's auc: 0.901047	valid's binary_logloss: 0.361057
# [500]	valid's auc: 0.901647	valid's binary_logloss: 0.359894
# [600]	valid's auc: 0.902093	valid's binary_logloss: 0.359058
# [700]	valid's auc: 0.902275	valid's binary_logloss: 0.35863
# [800]	valid's auc: 0.902486	valid's binary_logloss: 0.358235
# [900]	valid's auc: 0.90261	valid's binary_logloss: 0.357955
# [1000]	valid's auc: 0.902768	valid's binary_logloss: 0.357645
# [1100]	valid's auc: 0.90287	valid's binary_logloss: 0.357463
# [1200]	valid's auc: 0.902937	valid's binary_logloss: 0.357347
# [1300]	valid's auc: 0.902957	valid's binary_logloss: 0.357284
# Early stopping, best iteration is:
# [1272]	valid's auc: 0.902973	valid's binary_logloss: 0.357278
#
# Fold_3 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.893586	valid's binary_logloss: 0.38172
# [200]	valid's auc: 0.898348	valid's binary_logloss: 0.367341
# [300]	valid's auc: 0.90036	valid's binary_logloss: 0.363108
# [400]	valid's auc: 0.901489	valid's binary_logloss: 0.360869
# [500]	valid's auc: 0.902043	valid's binary_logloss: 0.359762
# [600]	valid's auc: 0.902397	valid's binary_logloss: 0.359091
# [700]	valid's auc: 0.902624	valid's binary_logloss: 0.358637
# [800]	valid's auc: 0.902819	valid's binary_logloss: 0.358309
# Early stopping, best iteration is:
# [830]	valid's auc: 0.902839	valid's binary_logloss: 0.358248
#
# Fold_4 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.893739	valid's binary_logloss: 0.380565
# [200]	valid's auc: 0.898837	valid's binary_logloss: 0.365938
# [300]	valid's auc: 0.901143	valid's binary_logloss: 0.361368
# [400]	valid's auc: 0.902249	valid's binary_logloss: 0.359232
# [500]	valid's auc: 0.902775	valid's binary_logloss: 0.35818
# [600]	valid's auc: 0.903007	valid's binary_logloss: 0.357664
# [700]	valid's auc: 0.903214	valid's binary_logloss: 0.35724
# [800]	valid's auc: 0.903261	valid's binary_logloss: 0.357061
# [900]	valid's auc: 0.903345	valid's binary_logloss: 0.356883
# [1000]	valid's auc: 0.903453	valid's binary_logloss: 0.356645
# Early stopping, best iteration is:
# [991]	valid's auc: 0.903463	valid's binary_logloss: 0.356636
#
# Fold_5 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.895881	valid's binary_logloss: 0.378965
# [200]	valid's auc: 0.900965	valid's binary_logloss: 0.363883
# [300]	valid's auc: 0.903001	valid's binary_logloss: 0.359523
# [400]	valid's auc: 0.903855	valid's binary_logloss: 0.357629
# [500]	valid's auc: 0.904391	valid's binary_logloss: 0.356475
# [600]	valid's auc: 0.904747	valid's binary_logloss: 0.355721
# [700]	valid's auc: 0.904949	valid's binary_logloss: 0.355262
# [800]	valid's auc: 0.905049	valid's binary_logloss: 0.354984
# [900]	valid's auc: 0.905143	valid's binary_logloss: 0.354734
# Early stopping, best iteration is:
# [892]	valid's auc: 0.905157	valid's binary_logloss: 0.354718
#
# Fold_6 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.891035	valid's binary_logloss: 0.384881
# [200]	valid's auc: 0.896324	valid's binary_logloss: 0.370507
# [300]	valid's auc: 0.898387	valid's binary_logloss: 0.366283
# [400]	valid's auc: 0.899486	valid's binary_logloss: 0.364268
# [500]	valid's auc: 0.900071	valid's binary_logloss: 0.363167
# [600]	valid's auc: 0.900402	valid's binary_logloss: 0.362531
# [700]	valid's auc: 0.900614	valid's binary_logloss: 0.362147
# [800]	valid's auc: 0.9008	valid's binary_logloss: 0.361776
# [900]	valid's auc: 0.900918	valid's binary_logloss: 0.361546
# [1000]	valid's auc: 0.900986	valid's binary_logloss: 0.361365
# [1100]	valid's auc: 0.900996	valid's binary_logloss: 0.361335
# Early stopping, best iteration is:
# [1057]	valid's auc: 0.90102	valid's binary_logloss: 0.361313
#
# Fold_7 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.893361	valid's binary_logloss: 0.380645
# [200]	valid's auc: 0.897839	valid's binary_logloss: 0.366945
# [300]	valid's auc: 0.899827	valid's binary_logloss: 0.362949
# [400]	valid's auc: 0.900658	valid's binary_logloss: 0.361258
# [500]	valid's auc: 0.901261	valid's binary_logloss: 0.360094
# [600]	valid's auc: 0.901553	valid's binary_logloss: 0.359514
# Early stopping, best iteration is:
# [629]	valid's auc: 0.901634	valid's binary_logloss: 0.359343
#
# Fold_8 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.893398	valid's binary_logloss: 0.381704
# [200]	valid's auc: 0.898506	valid's binary_logloss: 0.367087
# [300]	valid's auc: 0.900538	valid's binary_logloss: 0.362837
# [400]	valid's auc: 0.901678	valid's binary_logloss: 0.360639
# [500]	valid's auc: 0.902199	valid's binary_logloss: 0.359605
# [600]	valid's auc: 0.902496	valid's binary_logloss: 0.358996
# [700]	valid's auc: 0.902704	valid's binary_logloss: 0.358566
# [800]	valid's auc: 0.902841	valid's binary_logloss: 0.358292
# [900]	valid's auc: 0.902949	valid's binary_logloss: 0.358069
# [1000]	valid's auc: 0.903001	valid's binary_logloss: 0.357908
# [1100]	valid's auc: 0.903048	valid's binary_logloss: 0.357809
# Early stopping, best iteration is:
# [1080]	valid's auc: 0.903066	valid's binary_logloss: 0.357794
#
# Fold_9 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.89445	valid's binary_logloss: 0.37979
# [200]	valid's auc: 0.899292	valid's binary_logloss: 0.365453
# [300]	valid's auc: 0.901327	valid's binary_logloss: 0.361048
# [400]	valid's auc: 0.902211	valid's binary_logloss: 0.35914
# [500]	valid's auc: 0.902688	valid's binary_logloss: 0.358142
# [600]	valid's auc: 0.903059	valid's binary_logloss: 0.357427
# [700]	valid's auc: 0.90333	valid's binary_logloss: 0.356934
# [800]	valid's auc: 0.903545	valid's binary_logloss: 0.356543
# [900]	valid's auc: 0.903632	valid's binary_logloss: 0.356332
# [1000]	valid's auc: 0.903727	valid's binary_logloss: 0.356126
# [1100]	valid's auc: 0.903739	valid's binary_logloss: 0.356062
# Early stopping, best iteration is:
# [1069]	valid's auc: 0.903769	valid's binary_logloss: 0.356042
#
# Fold_10 Training ================================
#
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# Training until validation scores don't improve for 50 rounds
# [100]	valid's auc: 0.893221	valid's binary_logloss: 0.382143
# [200]	valid's auc: 0.898324	valid's binary_logloss: 0.367578
# [300]	valid's auc: 0.90049	valid's binary_logloss: 0.363143
# [400]	valid's auc: 0.901413	valid's binary_logloss: 0.361265
# [500]	valid's auc: 0.901936	valid's binary_logloss: 0.360213
# [600]	valid's auc: 0.902256	valid's binary_logloss: 0.359592
# [700]	valid's auc: 0.902441	valid's binary_logloss: 0.359223
# [800]	valid's auc: 0.902604	valid's binary_logloss: 0.358896
# [900]	valid's auc: 0.902718	valid's binary_logloss: 0.358717
# [1000]	valid's auc: 0.902834	valid's binary_logloss: 0.35853
# [1100]	valid's auc: 0.902859	valid's binary_logloss: 0.358451
# [1200]	valid's auc: 0.902949	valid's binary_logloss: 0.358327
# Early stopping, best iteration is:
# [1248]	valid's auc: 0.902983	valid's binary_logloss: 0.358274

# %%
df_importance = pd.concat(df_importance_list)
df_importance = df_importance.groupby(['column'])['importance'].agg(
    'mean').sort_values(ascending=False).reset_index()
df_importance
# Out:
#                                                 column  importance
# 0              p1_prior_days_to_insure_target_enc_mean      3107.1
# 1        suiche_nonauto_nprem_20_ratio_target_enc_mean      2678.4
# 2                              regdays_target_enc_mean      2519.4
# 3                             tp_ratio_target_enc_mean      2502.8
# 4                   p1_census_register_target_enc_mean      2484.3
# 5                  active_90_365_ratio_target_enc_mean      2188.1
# 6                              p1_prior_days_to_insure      2145.7
# 7                                  active_90_365_ratio      2126.3
# 8                        p1_prior_days_to_insure_count      2042.4
# 9        suiche_nonauto_nprem_19_ratio_target_enc_mean      2029.1
# 10                  active_90_365_diff_target_enc_mean      1974.2
# 11                                    od_tp_ratio_2ord      1973.1
# 12                                  active_90_365_diff      1969.9
# 13                                             regdays      1903.8
# 14                                        nprem_lydiff      1896.9
# 15                            nprem_ly_target_enc_mean      1881.8
# 16                     p2_client_grade_target_enc_mean      1868.8
# 17                            p1_census_register_count      1864.3
# 18                              series_target_enc_mean      1847.2
# 19                       make_cn_count_target_enc_mean      1834.4
# 20                       nprem_20ratio_target_enc_mean      1824.1
# 21                       suiche_nonauto_nprem_20_ratio      1817.6
# 22             service_score_available_target_enc_mean      1795.4
# 23                                  active_30_365_diff      1788.2
# 24             dpt_p1_census_register_regdays_2ordmean      1786.9
# 25   dpt_p1_census_register_suiche_nonauto_nprem_20...      1772.9
# 26                       nprem_lyratio_target_enc_mean      1770.6
# 27                                            tp_ratio      1724.8
# 28   dpt_p1_census_register_suiche_nonauto_nprem_20...      1712.9
# 29                                              p1_age      1699.2
# 30   dpt_p1_census_register_p1_prior_days_to_insure...      1679.1
# 31                                       make_cn_count      1673.0
# 32              dpt_p1_census_register_ncd_ly_2ordmean      1638.9
# 33   dpt_p1_census_register_active_90_365_ratio_2or...      1627.4
# 34                       suiche_nonauto_nprem_20_ydiff      1610.6
# 35                               capab_target_enc_mean      1552.6
# 36                 active_30_365_ratio_target_enc_mean      1534.6
# 37    dpt_p2_client_grade_active_90_365_ratio_2ordmean      1514.3
# 38                                      tp_ratio_count      1511.3
# 39                            brand_cn_target_enc_mean      1448.7
# 40            dpt_p1_census_register_tp_ratio_2ordmean      1433.1
# 41                                        series_count      1419.5
# 42                                          active_365      1414.1
# 43                                      nprem_ly_count      1412.1
# 44                                            od_ratio      1408.2
# 45                                   od_tp_ratio_2diff      1371.4
# 46                                 dpt_target_enc_mean      1358.8
# 47                             npremly_car_value_ratio      1326.1
# 48                       suiche_nonauto_nprem_19_ratio      1325.3
# 49                dpt_p2_client_grade_regdays_2ordmean      1308.6
# 50                     make_cn_cartype_target_enc_mean      1303.8
# 51             make_cn_cartype_0_count_target_enc_mean      1303.4
# 52                            personas_target_enc_mean      1302.0
# 53                                        p1_age_count      1300.7
# 54   dpt_p2_client_grade_p1_prior_days_to_insure_2o...      1300.4
# 55                                            newvalue      1289.4
# 56                      suiche_nonauto_amount_20_count      1272.3
# 57                                       nprem_lyratio      1272.2
# 58                            suiche_nonauto_amount_20      1250.8
# 59                 dpt_p2_client_grade_ncd_ly_2ordmean      1229.8
# 60                                 active_30_365_ratio      1218.2
# 61                        trademark_cn_target_enc_mean      1216.1
# 62         dpt_ncd_ly_p1_prior_days_to_insure_2ordmean      1185.3
# 63                                       nprem_20ratio      1178.6
# 64                      suiche_nonauto_nprem_20_yratio      1162.9
# 65   dpt_ncd_ly_suiche_nonauto_nprem_20_ydiff_2ordmean      1162.4
# 66                                     bi_renewal_year      1160.5
# 67                                      nprem_tp_count      1158.5
# 68                                   active_30_90_diff      1149.3
# 69                                            nprem_tp      1146.5
# 70               make_cn_cartype_count_target_enc_mean      1140.7
# 71                                    nprem_od_percent      1138.6
# 72   dpt_p2_client_grade_suiche_nonauto_nprem_20_yd...      1127.1
# 73                                         capab_count      1115.6
# 74                               make_cn_cartype_count      1108.8
# 75             dpt_ncd_ly_active_90_365_ratio_2ordmean      1105.7
# 76                                  active_30_90_ratio      1102.9
# 77                             service_score_available      1091.2
# 78                                           reg_month      1076.5
# 79                              ncd_ly_target_enc_mean      1060.8
# 80                                               capab      1047.9
# 81                           dur_personal_insurance_90      1046.4
# 82                      personas_count_target_enc_mean      1031.1
# 83                            npremtot_car_value_ratio      1030.3
# 84                                        nprem_20diff      1019.4
# 85                        dpt_ncd_ly_tp_ratio_2ordmean      1015.9
# 86                                    nprem_tp_percent       988.8
# 87              suiche_nonauto_nprem_20_19_ratio_2diff       982.3
# 88                      suiche_nonauto_nprem_19_2ydiff       981.2
# 89                                      brand_cn_count       977.1
# 90                             make_cn_cartype_0_count       964.1
# 91                             suiche_nonauto_nprem_20       957.9
# 92                                            nprem_ly       949.6
# 93                       service_score_available_count       949.4
# 94                       personas_p2_client_grade_mean       946.4
# 95                              nprem_odtp_percent_add       946.1
# 96             personas_dur_personal_insurance_90_mean       940.2
# 97               suiche_nonauto_nprem_20_19_ratio_2ord       937.4
# 98                             nprem_odtp_percent_diff       925.8
# 99                                           active_90       900.2
# 100              dpt_p2_client_grade_tp_ratio_2ordmean       878.9
# 101                                 trademark_cn_count       843.9
# 102                    dptservice_score_available_mean       841.3
# 103              personas_service_score_available_mean       835.1
# 104                     suiche_nonauto_amount_19_count       830.3
# 105                           personas_active_365_mean       828.3
# 106                               personas_clmnum_mean       822.6
# 107                           suiche_nonauto_amount_19       814.5
# 108                  personas_active_90_365_ratio_mean       810.4
# 109                              dptnprem_lyratio_mean       806.2
# 110                                           nprem_od       805.5
# 111                             personas_tp_ratio_mean       802.9
# 112  dpt_ncd_ly_suiche_nonauto_nprem_20_ratio_2ordmean       801.6
# 113                                              si_od       798.9
# 114                                          nprem_tot       798.0
# 115          personas_f2_cust_housing_price_total_mean       790.3
# 116  dpt_p2_client_grade_suiche_nonauto_nprem_20_ra...       770.5
# 117        personas_suiche_nonauto_nprem_20_ydiff_mean       769.4
# 118                                    p2_client_grade       766.8
# 119                                        birth_month       765.8
# 120                            suiche_nonauto_nprem_19       718.2
# 121                 dptservice_score_available_nunique       717.3
# 122                                      dptsi_tp_mean       716.7
# 123                                  active_7_30_ratio       688.8
# 124                      suiche_nonauto_nprem_17_ratio       685.5
# 125                                personas_si_tp_mean       677.7
# 126                                 personas_cno_count       673.3
# 127                    suiche_nonauto_nprem_19_2yratio       659.2
# 128                                personas_seats_mean       657.5
# 129                                          vld_ratio       654.7
# 130                                 dptactive_365_mean       649.9
# 131                        personas_nprem_lyratio_mean       649.7
# 132                        f2_cust_housing_price_total       644.7
# 133                                     dptncd_ly_mean       644.7
# 134                dptsuiche_nonauto_amount_20_nunique       632.8
# 135                                          vlp_ratio       626.1
# 136                                      dptseats_mean       622.4
# 137                               personas_ncd_ly_mean       614.5
# 138                             personas_newvalue_mean       614.4
# 139                  dptdur_personal_insurance_90_mean       611.4
# 140                                                dpt       608.4
# 141                            car_housing_value_ratio       605.9
# 142                     personas_od_tp_ratio_2ord_mean       600.0
# 143                                   dptod_ratio_mean       599.4
# 144                             personas_od_ratio_mean       590.9
# 145                      personas_bi_renewal_year_mean       586.8
# 146                                     dptclmnum_mean       568.6
# 147                            dptbi_renewal_year_mean       566.7
# 148                            dptp2_client_grade_mean       566.7
# 149                            dpttrademark_cn_nunique       564.5
# 150                                personas_capab_mean       555.4
# 151                                           bt_ratio       551.8
# 152                              personas_regdays_mean       547.5
# 153                             personas_nprem_ly_mean       545.6
# 154                                    dptregdays_mean       528.0
# 155              dptsuiche_nonauto_nprem_20_ydiff_mean       506.3
# 156                      suiche_nonauto_nprem_17_ydiff       487.8
# 157                     suiche_nonauto_nprem_17_yratio       485.7
# 158                       npremtot_housing_value_ratio       483.7
# 159                           dptod_tp_ratio_2ord_mean       483.6
# 160                                             clmnum       441.3
# 161             suiche_nonauto_nprem_20_19_yratio_2ord       432.0
# 162                               xz_xb_co_15_55_count       406.8
# 163                            suiche_nonauto_nprem_17       405.4
# 164                                     personas_count       378.9
# 165                           suiche_nonauto_amount_17       377.8
# 166                                          nprem_vld       376.7
# 167                                          nprem_vlp       367.0
# 168             suiche_nonauto_nprem_20_17_yratio_2ord       345.1
# 169                                          active_30       322.1
# 170                                            reg_day       302.1
# 171                                             ncd_ly       296.8
# 172                                              si_tp       285.3
# 173                                           reg_year       283.6
# 174                            suiche_nonauto_nprem_16       243.9
# 175                                           nprem_bt       225.7
# 176                            make_cn_cartype_1_count       223.5
# 177                               p1_service_offer_cnt       211.6
# 178                           suiche_nonauto_amount_16       181.9
# 179                                              si_bt       178.3
# 180                               p3_service_use_ratio       154.8
# 181                                           active_7       151.3
# 182                                              seats        95.5
# 183                                             si_vld        89.1
# 184                                 p3_service_use_cnt        76.2
# 185                                             si_vlp        61.3

# %%
os.makedirs('sub_lgbm', exist_ok=True)
res_oof = pd.DataFrame()
res_oof['carid'] = df_train['carid']
res_oof['y1_is_purchase'] = df_train['y1_is_purchase']
res_oof['probability'] = oof
score = roc_auc_score(df_train['y1_is_purchase'], res_oof['probability'])
print(score)
print('开始储存oof')
res_oof.to_csv('sub_lgbm/lgbm_seed_'+str(seed)+f'_train_{score}.csv',index = False)
print(res_oof.shape)
res_oof.head()
# Out:
# 0.9032069267925168
# 开始储存oof
# (684283, 3)
#                                           carid  y1_is_purchase  probability
# 0  WY4N+MOjfIx8wJ3j6GhlA4qEfL71brEUkqbB0SSdqkI=             0.0     0.000019
# 1  DXMuODygH0ddFea7SIoAOhF4134Bx4TPvkkPi6WCdzU=             1.0     0.904991
# 2  waWCEYZJqj9PYxFdVeVLkpCNf/n0BdXPFi1iHlk0WWk=             1.0     0.820730
# 3  nyRm/VviYGDpy2errRWE206SaYkVuqeclusAtXEU9v8=             1.0     0.545280
# 4  LacSDMaoqD0AJRqCeYaGUu343r4NQiVuiFc9hyjLcMI=             1.0     0.995210

# %%
# os.makedirs('sub_lgbm', exist_ok=True)
prediction.to_csv(f'sub_lgbm/lgbm_seed_'+str(seed)+f'_test_{score}.csv', index=False)
prediction.head()
# Out:
#                                                carid     label
# 684283  FbOikOdqe5f3mRYDAgnBH2PwI5I+egmzWyNwjmgAuWs=  0.000019
# 684284  WTO/cku1nHO592k9j56on2UzMmx8OLhw8peccj1m13I=  0.629416
# 684285  ow79MMeuFgFY92UOVjaECsaNPl5cRXAi3M5ZsB4Rt/s=  0.302148
# 684286  nuO8DDjdXKFMt5Of70LlXMlFoLDX0OMSSBYnNYnqTyQ=  0.900784
# 684287  j4gIDul5h/7IBEYq4y8oAr2+tSWj/NdsIFbGzDtpTsk=  0.507833

# %%
#查看模型的特征重要性
import matplotlib.pyplot as plt 
from matplotlib import cm
score = pd.DataFrame()
score['fea_name'] = df_importance['column']
score['fea'] = df_importance['importance']
score = score.sort_values(['fea'], ascending=False)
temp = pd.DataFrame()
temp = score[:320]
color = cm.jet(temp['fea']/temp['fea'].max())
plt.figure(figsize=(10, 30))
plt.barh(temp['fea_name'],temp['fea'],height =0.8,color=color,alpha=0.8)
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/60E575D944604BF78BAAA24BE51E7766/qu2d80uq1z.png">

# %% [markdown]
# ## 分特征查看重要性

# %%
show_list = []
for s in df_train.columns:
    if 'dpt' in s:
        show_list.append(s)
print(show_list)
show=score[score['fea_name'].isin(show_list)]
show
# Out:
# ['dpt', 'dpttrademark_cn_nunique', 'dptsuiche_nonauto_amount_20_nunique', 'dptservice_score_available_nunique', 'dptservice_score_available_mean', 'dptdur_personal_insurance_90_mean', 'dptactive_365_mean', 'dptncd_ly_mean', 'dptbi_renewal_year_mean', 'dptclmnum_mean', 'dptseats_mean', 'dptregdays_mean', 'dptod_ratio_mean', 'dptp2_client_grade_mean', 'dptod_tp_ratio_2ord_mean', 'dptnprem_lyratio_mean', 'dptsi_tp_mean', 'dptsuiche_nonauto_nprem_20_ydiff_mean', 'dpt_ncd_ly_p1_prior_days_to_insure_2ordmean', 'dpt_ncd_ly_active_90_365_ratio_2ordmean', 'dpt_ncd_ly_tp_ratio_2ordmean', 'dpt_ncd_ly_suiche_nonauto_nprem_20_ydiff_2ordmean', 'dpt_ncd_ly_suiche_nonauto_nprem_20_ratio_2ordmean', 'dpt_p1_census_register_active_90_365_ratio_2ordmean', 'dpt_p1_census_register_p1_prior_days_to_insure_2ordmean', 'dpt_p1_census_register_tp_ratio_2ordmean', 'dpt_p1_census_register_regdays_2ordmean', 'dpt_p1_census_register_ncd_ly_2ordmean', 'dpt_p1_census_register_suiche_nonauto_nprem_20_ydiff_2ordmean', 'dpt_p1_census_register_suiche_nonauto_nprem_20_ratio_2ordmean', 'dpt_p2_client_grade_active_90_365_ratio_2ordmean', 'dpt_p2_client_grade_p1_prior_days_to_insure_2ordmean', 'dpt_p2_client_grade_tp_ratio_2ordmean', 'dpt_p2_client_grade_regdays_2ordmean', 'dpt_p2_client_grade_ncd_ly_2ordmean', 'dpt_p2_client_grade_suiche_nonauto_nprem_20_ydiff_2ordmean', 'dpt_p2_client_grade_suiche_nonauto_nprem_20_ratio_2ordmean', 'dpt_target_enc_mean']
#                                               fea_name     fea
# 24             dpt_p1_census_register_regdays_2ordmean  1786.9
# 25   dpt_p1_census_register_suiche_nonauto_nprem_20...  1772.9
# 28   dpt_p1_census_register_suiche_nonauto_nprem_20...  1712.9
# 30   dpt_p1_census_register_p1_prior_days_to_insure...  1679.1
# 32              dpt_p1_census_register_ncd_ly_2ordmean  1638.9
# 33   dpt_p1_census_register_active_90_365_ratio_2or...  1627.4
# 37    dpt_p2_client_grade_active_90_365_ratio_2ordmean  1514.3
# 40            dpt_p1_census_register_tp_ratio_2ordmean  1433.1
# 46                                 dpt_target_enc_mean  1358.8
# 49                dpt_p2_client_grade_regdays_2ordmean  1308.6
# 54   dpt_p2_client_grade_p1_prior_days_to_insure_2o...  1300.4
# 59                 dpt_p2_client_grade_ncd_ly_2ordmean  1229.8
# 62         dpt_ncd_ly_p1_prior_days_to_insure_2ordmean  1185.3
# 65   dpt_ncd_ly_suiche_nonauto_nprem_20_ydiff_2ordmean  1162.4
# 72   dpt_p2_client_grade_suiche_nonauto_nprem_20_yd...  1127.1
# 75             dpt_ncd_ly_active_90_365_ratio_2ordmean  1105.7
# 85                        dpt_ncd_ly_tp_ratio_2ordmean  1015.9
# 100              dpt_p2_client_grade_tp_ratio_2ordmean   878.9
# 102                    dptservice_score_available_mean   841.3
# 109                              dptnprem_lyratio_mean   806.2
# 112  dpt_ncd_ly_suiche_nonauto_nprem_20_ratio_2ordmean   801.6
# 116  dpt_p2_client_grade_suiche_nonauto_nprem_20_ra...   770.5
# 121                 dptservice_score_available_nunique   717.3
# 122                                      dptsi_tp_mean   716.7
# 130                                 dptactive_365_mean   649.9
# 133                                     dptncd_ly_mean   644.7
# 134                dptsuiche_nonauto_amount_20_nunique   632.8
# 136                                      dptseats_mean   622.4
# 139                  dptdur_personal_insurance_90_mean   611.4
# 140                                                dpt   608.4
# 143                                   dptod_ratio_mean   599.4
# 146                                     dptclmnum_mean   568.6
# 147                            dptbi_renewal_year_mean   566.7
# 148                            dptp2_client_grade_mean   566.7
# 149                            dpttrademark_cn_nunique   564.5
# 154                                    dptregdays_mean   528.0
# 155              dptsuiche_nonauto_nprem_20_ydiff_mean   506.3
# 159                           dptod_tp_ratio_2ord_mean   483.6

# %%
# !wget -nv -O heywhale_submit https://cdn.kesci.com/submit_tool/v4/heywhale_submit&&chmod +x heywhale_submit
# !./heywhale_submit -token ff040f9de88e681b -file /home/mw/work/sub_lgbm/lgbm_seed_1024_test_0.9032069267925168.csv
# Out:
# 2021-06-02 08:13:53 URL:https://cdn.kesci.com/submit_tool/v4/heywhale_submit [7357446/7357446] -> "heywhale_submit" [1]
# Heywhale Submit Tool 4.0.0
#
# > 已验证Token
# > 提交文件 /home/mw/work/sub_lgbm/lgbm_seed_1024_test_0.9032069267925168.csv (5057.46 KiB), Target Qiniu
# > 已上传 100 %
# > 文件已上传
# > 服务器响应: 200 提交成功，请等待评审完成
# > 提交完成
